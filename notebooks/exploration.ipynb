# %%
# Check for changes in .py files every time a cell is ran
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# This adds the parent directory (project root) to the search path
sys.path.append(os.path.abspath(".."))

# %%
# Import function from database.py for sql files executing
from src.database import execute_sql_file
from pathlib import Path

# %%
# Testing the function
# Resolve the path to the SQL file relative to the notebook
query_path = Path("../queries/00_get_tables.sql")

# Execute query and store results
tables = execute_sql_file(query_path)

# Print results
print(tables)
# Out:
# [('countries',), ('grapes',), ('wineries',), ('flavor_groups',), ('keywords',), ('regions',), ('most_used_grapes_per_country',), ('toplists',), ('wines',), ('vintages',), ('keywords_wine',), ('vintage_toplists_rankings',)]

# %% [markdown]
# ## Business questions

# %% [markdown]
# ### 1. We want to highlight 10 wines to increase our sales. Which ones should we choose and why?

# %%
query_path = Path("../queries/01_highlight_10_wines.sql") 

top_10_wines = execute_sql_file(query_path)

for wine, ratings_avg, ratings_count in top_10_wines:
    print(f"{wine=}, {ratings_avg=}, {ratings_count=}")
# Out:
# wine='Unico', ratings_avg=4.7, ratings_count=45140
# wine='Sauternes', ratings_avg=4.7, ratings_count=44126
# wine='Special Selection Cabernet Sauvignon', ratings_avg=4.7, ratings_count=41236
# wine='Pomerol', ratings_avg=4.7, ratings_count=32157
# wine='Grange', ratings_avg=4.7, ratings_count=24356
# wine='Toscana', ratings_avg=4.7, ratings_count=16284
# wine='Unico Reserva Especial Edición', ratings_avg=4.7, ratings_count=13025
# wine='Almaviva', ratings_avg=4.6, ratings_count=48075
# wine='Bolgheri Superiore', ratings_avg=4.6, ratings_count=47939
# wine='Château Margaux (Premier Grand Cru Classé)', ratings_avg=4.6, ratings_count=45350

# %% [markdown]
# Visualization process
#
# Created a visualizations.py script containing all visualization functions

# %% [markdown]
# 1.a 1st question visualization
#
# Scatter Plot:
#
# X-Axis: Number of Ratings (ratings_count)
#
# Y-Axis: Average Rating (ratings_average)
#
# Background: The rest of the database plotted as faint, transparent markers to show the overarching trend.
#
# The Highlight: Our top 10 wines plotted as prominent, colored markers inside our defined "Sweet Spot" box.

# %%
# Import and call 1st question visual function
from src.visualizations import plot_top_10_bar

fig1 = plot_top_10_bar(top_10_wines)
fig1.show()

# %% [markdown]
# ### Here is the exact framework for a data story:
#
# 1. The Goal (The Hook): Acknowledge what the business wants (e.g., increase sales).
# 2. The Strategy (The Pivot): Explain how you manipulated the data without using technical terms.
# 3. The Result (The Payoff): Present the solution and explicitly state the business value.

# %% [markdown]
# 1.b Explanation for stakeholders
#
# To drive new sales, we must avoid spending our marketing budget on over-saturated 'mega-brands' that our customers already know and buy. Instead, we targeted a 'Sweet Spot' of 10 Hidden Gems. These are wines that have definitively proven their elite quality across thousands of customer reviews, but have not yet peaked in mainstream fame. By highlighting these specific wines, we guarantee we are introducing highly reliable, top-tier products to a fresh audience, which maximizes our return on investment

# %% [markdown]
# The Breakdown: * We translated the ratings_count < 50000 cap into "not yet peaked in mainstream fame."
#
# We translated the ratings_count > 10000 floor into "definitively proven their elite quality."
#
# We provided the "Why" (Return on Investment).

# %% [markdown]
# ### 2. We have a marketing budget for this year. Which country should we prioritise and why?

# %% [markdown]
# We need a country that produces elite wine (Signal) with high consistency (Shield), but currently lacks the massive user adoption (Saturation) of the heavyweights.

# %%
query_path = Path("../queries/02_marketing_country.sql") 

top_country_marketing = execute_sql_file(query_path)

for country, total_clients, total_wines_country, average_total_ratings in top_country_marketing:
    print(f"{country=}, {total_clients=}, {total_wines_country=}, {average_total_ratings=}")
# Out:
# country='Espagne', total_clients=2264396, total_wines_country=94, average_total_ratings=4.44
# country='Italie', total_clients=4270717, total_wines_country=383, average_total_ratings=4.43
# country='France', total_clients=5973301, total_wines_country=331, average_total_ratings=4.45
# country='États-Unis', total_clients=12273684, total_wines_country=74, average_total_ratings=4.49

# %% [markdown]
# Explanation to stakeholders
#
# To maximize the return on our marketing budget, we analyzed our top-tier wine producing nations. While heavyweights like the United States, France, and Italy produce massive volumes of highly-rated wine, their markets are already heavily saturated with millions of existing users. Therefore, we recommend prioritizing Spain. Spain is a 'High-Quality Underdog.' It possesses the infrastructure to produce a massive variety of elite wines (94 distinct wines averaging a 4.44 rating), but currently has a fraction of the user base (2.2 million). Investing our budget here guarantees we are pushing a statistically proven, premium product into a market with massive untapped growth potential.

# %% [markdown]
# The Mechanics: This paragraph starts with the business goal (ROI), acknowledges the competition to build trust, presents the data (94 wines, 4.44 rating, 2.2m users), and closes with the strategic justification.

# %% [markdown]
# ### 3. We would like to give awards to the best wineries. Come up with 3 relevant ones. Which wineries should we choose and why?

# %% [markdown]
# The awards:
#
# 1. The Time Capsule Award: Oldest Registered Bottle winery
# 2. The Prolific Elite Award: Highest volume production of wines
# 3. The Flawless Boutique: Masters of small-batch perfection

# %% [markdown]
# ### The Time Capsule Award: Oldest Registered Bottle winery

# %%
query_path = Path("../queries/03_award_1.sql") 

award_1 = execute_sql_file(query_path)

print(award_1)
# Out:
# [('Tignanello', 'Quinta do Crasto Colheita Porto 2003', 2003)]

# %% [markdown]
# This award recognizes the winery that has preserved the deepest historical footprint in our platform. By analyzing our records and strictly filtering out incomplete data, we searched for the oldest authenticated bottle. The award goes to Tignanello. Their 2003 vintage stands as the oldest verified wine in our collection, representing a deep, enduring legacy in the wine market.

# %% [markdown]
# ### The Prolific Elite Award: Highest volume production of wines

# %%
query_path = Path("../queries/03_award_2.sql") 

award_2 = execute_sql_file(query_path)

print(award_2)
# Out:
# [('Corte di Cama Sforzato di Valtellina', 1, 4.5)]

# %% [markdown]
# Due to constraints in the relational mapping between the wineries and wines tables, the maximum queryable production volume for any single entity in this dataset is 1 unit. When applying the 'Elite' criteria (average_ratings > 4.0), Corte di Cama Sforzato di Valtellina is selected as the top candidate that satisfies both the maximum available volume and the quality threshold.

# %% [markdown]
# ### The Flawless Boutique: Masters of small-batch perfection

# %%
query_path = Path("../queries/03_award_3.sql") 

award_3 = execute_sql_file(query_path)

print(award_3)
# Out:
# [("Tenuta Tignanello 'Solaia'", 4.5, 1)]

# %% [markdown]
# Tenuta Tignanello 'Solaia' is awarded 'The Flawless Boutique' designation. By isolating the masters of small-batch perfection (wineries producing fewer than 5 wines), we found that Tenuta Tignanello 'Solaia' achieved the absolute highest average rating in the database. This validates their ability to consistently deliver top-tier quality across their limited production.

# %% [markdown]
# ### 4. We have detected that a big cluster of customers like a specific combination of tastes. We have identified a few primary keywords that match this. We would like you to find all the wines that have those keywords:
# - coffee
# - toast
# - green apple
# - cream
# - citrus
#
# To ensure the accuracy of our selection, ensure that more than 10 users confirmed those keywords. Also, identify the group_name related to those keywords.

# %%
query_path = Path("../queries/04_flavor_groups.sql") 

flavor_groups = execute_sql_file(query_path)

for flavor in flavor_groups:
    print(flavor)
# Out:
# ("'Giulio Ferrari' Riserva del Fondatore", 'citrus', 66, 'citrus_fruit')
# ("'Giulio Ferrari' Riserva del Fondatore", 'cream', 72, 'microbio')
# ("'Giulio Ferrari' Riserva del Fondatore", 'green apple', 15, 'tree_fruit')
# ("'Giulio Ferrari' Riserva del Fondatore", 'toast', 48, 'microbio')
# ("'Giulio Ferrari' Riserva del Fondatore", 'toast', 48, 'non_oak')
# ('25 anni Montefalco Sagrantino', 'coffee', 23, 'non_oak')
# ('25 anni Montefalco Sagrantino', 'coffee', 23, 'oak')
# ('5 Puttonyos Aszú (Blue Label)', 'citrus', 118, 'citrus_fruit')
# ('5 Puttonyos Aszú (Blue Label)', 'cream', 68, 'microbio')
# ('5 Puttonyos Aszú (Blue Label)', 'green apple', 12, 'tree_fruit')
# ('5 Puttonyos Aszú (Blue Label)', 'toast', 30, 'microbio')
# ('5 Puttonyos Aszú (Blue Label)', 'toast', 30, 'non_oak')
# ('5 Stelle Sfursat', 'coffee', 35, 'non_oak')
# ('5 Stelle Sfursat', 'coffee', 35, 'oak')
# ('50 & 50', 'coffee', 13, 'non_oak')
# ('50 & 50', 'coffee', 13, 'oak')
# ('60 Sessantanni Old Vines Primitivo di Manduria', 'coffee', 136, 'non_oak')
# ('60 Sessantanni Old Vines Primitivo di Manduria', 'coffee', 136, 'oak')
# ('60 Sessantanni Old Vines Primitivo di Manduria', 'cream', 27, 'microbio')
# ('60 Sessantanni Old Vines Primitivo di Manduria', 'toast', 11, 'microbio')
# ('60 Sessantanni Old Vines Primitivo di Manduria', 'toast', 11, 'non_oak')
# ('80 Vecchie Vigne Primitivo di Manduria Old Vines', 'coffee', 12, 'non_oak')
# ('80 Vecchie Vigne Primitivo di Manduria Old Vines', 'coffee', 12, 'oak')
# ('ARTEMIS Cabernet Sauvignon', 'coffee', 116, 'non_oak')
# ('ARTEMIS Cabernet Sauvignon', 'coffee', 116, 'oak')
# ('ARTEMIS Cabernet Sauvignon', 'cream', 93, 'microbio')
# ('ARTEMIS Cabernet Sauvignon', 'toast', 60, 'microbio')
# ('ARTEMIS Cabernet Sauvignon', 'toast', 60, 'non_oak')
# ('Aconcagua Valley', 'coffee', 68, 'non_oak')
# ('Aconcagua Valley', 'coffee', 68, 'oak')
# ('Aconcagua Valley', 'cream', 31, 'microbio')
# ('Aconcagua Valley', 'toast', 29, 'microbio')
# ('Aconcagua Valley', 'toast', 29, 'non_oak')
# ("Ai Suma Barbera d'Asti", 'coffee', 13, 'non_oak')
# ("Ai Suma Barbera d'Asti", 'coffee', 13, 'oak')
# ("Aile d'Argent Blanc Bordeaux", 'citrus', 94, 'citrus_fruit')
# ("Aile d'Argent Blanc Bordeaux", 'cream', 37, 'microbio')
# ("Aile d'Argent Blanc Bordeaux", 'green apple', 12, 'tree_fruit')
# ('Alexander Valley Cabernet Sauvignon', 'coffee', 84, 'non_oak')
# ('Alexander Valley Cabernet Sauvignon', 'coffee', 84, 'oak')
# ('Alexander Valley Cabernet Sauvignon', 'cream', 46, 'microbio')
# ('Alexander Valley Cabernet Sauvignon', 'toast', 31, 'microbio')
# ('Alexander Valley Cabernet Sauvignon', 'toast', 31, 'non_oak')
# ('Almaviva', 'coffee', 123, 'non_oak')
# ('Almaviva', 'coffee', 123, 'oak')
# ('Almaviva', 'cream', 41, 'microbio')
# ('Almaviva', 'toast', 30, 'microbio')
# ('Almaviva', 'toast', 30, 'non_oak')
# ('Altero Brunello di Montalcino', 'coffee', 13, 'non_oak')
# ('Altero Brunello di Montalcino', 'coffee', 13, 'oak')
# ('Amarone della Valpolicella', 'coffee', 44, 'non_oak')
# ('Amarone della Valpolicella', 'coffee', 44, 'oak')
# ('Amarone della Valpolicella', 'cream', 21, 'microbio')
# ('Amarone della Valpolicella Classico', 'citrus', 31, 'citrus_fruit')
# ('Amarone della Valpolicella Classico', 'coffee', 434, 'non_oak')
# ('Amarone della Valpolicella Classico', 'coffee', 434, 'oak')
# ('Amarone della Valpolicella Classico', 'cream', 141, 'microbio')
# ('Amarone della Valpolicella Classico', 'toast', 68, 'microbio')
# ('Amarone della Valpolicella Classico', 'toast', 68, 'non_oak')
# ('Amarone della Valpolicella Classico Riserva (Sergio Zenato)', 'coffee', 36, 'non_oak')
# ('Amarone della Valpolicella Classico Riserva (Sergio Zenato)', 'coffee', 36, 'oak')
# ('Amarone della Valpolicella Classico Riserva (Sergio Zenato)', 'cream', 12, 'microbio')
# ('Amarone della Valpolicella Monte Lodoletta', 'coffee', 32, 'non_oak')
# ('Amarone della Valpolicella Monte Lodoletta', 'coffee', 32, 'oak')
# ('Amour de Deutz Millesimé Rosé Brut Champagne', 'citrus', 13, 'citrus_fruit')
# ('Amour de Deutz Millesimé Rosé Brut Champagne', 'cream', 18, 'microbio')
# ('Amour de Deutz Millésimé Brut Champagne', 'citrus', 89, 'citrus_fruit')
# ('Amour de Deutz Millésimé Brut Champagne', 'cream', 92, 'microbio')
# ('Amour de Deutz Millésimé Brut Champagne', 'green apple', 25, 'tree_fruit')
# ('Amour de Deutz Millésimé Brut Champagne', 'toast', 95, 'microbio')
# ('Amour de Deutz Millésimé Brut Champagne', 'toast', 95, 'non_oak')
# ('Ares', 'coffee', 11, 'non_oak')
# ('Ares', 'coffee', 11, 'oak')
# ('Aszú 6 puttonyos', 'citrus', 27, 'citrus_fruit')
# ('Aszú 6 puttonyos', 'cream', 17, 'microbio')
# ("Avizoise Blanc de Blancs Extra Brut Champagne Grand Cru 'Avize'", 'citrus', 26, 'citrus_fruit')
# ("Avizoise Blanc de Blancs Extra Brut Champagne Grand Cru 'Avize'", 'cream', 30, 'microbio')
# ("Avizoise Blanc de Blancs Extra Brut Champagne Grand Cru 'Avize'", 'green apple', 20, 'tree_fruit')
# ("Avizoise Blanc de Blancs Extra Brut Champagne Grand Cru 'Avize'", 'toast', 28, 'microbio')
# ("Avizoise Blanc de Blancs Extra Brut Champagne Grand Cru 'Avize'", 'toast', 28, 'non_oak')
# ('Barbaresco', 'coffee', 67, 'non_oak')
# ('Barbaresco', 'coffee', 67, 'oak')
# ('Barbaresco Rabajà', 'coffee', 16, 'non_oak')
# ('Barbaresco Rabajà', 'coffee', 16, 'oak')
# ('Barolo Bricco Rocche', 'coffee', 12, 'non_oak')
# ('Barolo Bricco Rocche', 'coffee', 12, 'oak')
# ('Barolo Brunate', 'coffee', 16, 'non_oak')
# ('Barolo Brunate', 'coffee', 16, 'oak')
# ('Barolo Cascina Francia', 'coffee', 13, 'non_oak')
# ('Barolo Cascina Francia', 'coffee', 13, 'oak')
# ('Barolo Ciabot Mentin Ginestra', 'coffee', 12, 'non_oak')
# ('Barolo Ciabot Mentin Ginestra', 'coffee', 12, 'oak')
# ('Barolo Le Vigne', 'coffee', 18, 'non_oak')
# ('Barolo Le Vigne', 'coffee', 18, 'oak')
# ('Barolo Prapò', 'coffee', 13, 'non_oak')
# ('Barolo Prapò', 'coffee', 13, 'oak')
# ('Barolo Riserva', 'coffee', 33, 'non_oak')
# ('Barolo Riserva', 'coffee', 33, 'oak')
# ('Barolo Riserva Bricco Boschis Vigna San Giuseppe', 'coffee', 14, 'non_oak')
# ('Barolo Riserva Bricco Boschis Vigna San Giuseppe', 'coffee', 14, 'oak')
# ('Baron de L Pouilly-Fumé', 'citrus', 118, 'citrus_fruit')
# ('Baron de L Pouilly-Fumé', 'cream', 19, 'microbio')
# ('Baron de L Pouilly-Fumé', 'green apple', 48, 'tree_fruit')
# ('Barsac (Premier Grand Cru Classé)', 'citrus', 57, 'citrus_fruit')
# ('Barsac (Premier Grand Cru Classé)', 'cream', 65, 'microbio')
# ('Barsac (Premier Grand Cru Classé)', 'toast', 19, 'microbio')
# ('Barsac (Premier Grand Cru Classé)', 'toast', 19, 'non_oak')
# ('Barón de Chirel Rioja Reserva', 'coffee', 20, 'non_oak')
# ('Barón de Chirel Rioja Reserva', 'coffee', 20, 'oak')
# ('Barón de Chirel Rioja Reserva', 'toast', 16, 'microbio')
# ('Barón de Chirel Rioja Reserva', 'toast', 16, 'non_oak')
# ("Beaune 1er Cru 'Clos des Mouches' Blanc", 'citrus', 36, 'citrus_fruit')
# ("Beaune 1er Cru 'Clos des Mouches' Blanc", 'cream', 30, 'microbio')
# ('Belle Epoque Brut Champagne', 'citrus', 423, 'citrus_fruit')
# ('Belle Epoque Brut Champagne', 'coffee', 14, 'non_oak')
# ('Belle Epoque Brut Champagne', 'coffee', 14, 'oak')
# ('Belle Epoque Brut Champagne', 'cream', 207, 'microbio')
# ('Belle Epoque Brut Champagne', 'green apple', 224, 'tree_fruit')
# ('Belle Epoque Brut Champagne', 'toast', 239, 'microbio')
# ('Belle Epoque Brut Champagne', 'toast', 239, 'non_oak')
# ('Belondrade y Lurton', 'citrus', 105, 'citrus_fruit')
# ('Belondrade y Lurton', 'cream', 75, 'microbio')
# ('Belondrade y Lurton', 'green apple', 27, 'tree_fruit')
# ('Belondrade y Lurton', 'toast', 13, 'microbio')
# ('Belondrade y Lurton', 'toast', 13, 'non_oak')
# ('Ben Ryé Passito di Pantelleria', 'citrus', 80, 'citrus_fruit')
# ('Ben Ryé Passito di Pantelleria', 'cream', 35, 'microbio')
# ('Beyond the Clouds', 'citrus', 22, 'citrus_fruit')
# ('Beyond the Clouds', 'cream', 56, 'microbio')
# ('Beyond the Clouds', 'green apple', 13, 'tree_fruit')
# ('Bibbona', 'coffee', 26, 'non_oak')
# ('Bibbona', 'coffee', 26, 'oak')
# ('Bibbona', 'toast', 12, 'microbio')
# ('Bibbona', 'toast', 12, 'non_oak')
# ('Bienvenues-Bâtard-Montrachet Grand Cru', 'citrus', 18, 'citrus_fruit')
# ('Blanc', 'citrus', 25, 'citrus_fruit')
# ('Blanc', 'cream', 29, 'microbio')
# ('Blanc de Blancs Brut Champagne (Vintage)', 'citrus', 143, 'citrus_fruit')
# ('Blanc de Blancs Brut Champagne (Vintage)', 'cream', 92, 'microbio')
# ('Blanc de Blancs Brut Champagne (Vintage)', 'green apple', 62, 'tree_fruit')
# ('Blanc de Blancs Brut Champagne (Vintage)', 'toast', 56, 'microbio')
# ('Blanc de Blancs Brut Champagne (Vintage)', 'toast', 56, 'non_oak')
# ('Blanc de Blancs Brut Champagne Grand Cru', 'citrus', 152, 'citrus_fruit')
# ('Blanc de Blancs Brut Champagne Grand Cru', 'cream', 118, 'microbio')
# ('Blanc de Blancs Brut Champagne Grand Cru', 'green apple', 74, 'tree_fruit')
# ('Blanc de Blancs Brut Champagne Grand Cru', 'toast', 126, 'microbio')
# ('Blanc de Blancs Brut Champagne Grand Cru', 'toast', 126, 'non_oak')
# ('Blanc des Millénaires', 'citrus', 181, 'citrus_fruit')
# ('Blanc des Millénaires', 'coffee', 27, 'non_oak')
# ('Blanc des Millénaires', 'coffee', 27, 'oak')
# ('Blanc des Millénaires', 'cream', 149, 'microbio')
# ('Blanc des Millénaires', 'green apple', 66, 'tree_fruit')
# ('Blanc des Millénaires', 'toast', 160, 'microbio')
# ('Blanc des Millénaires', 'toast', 160, 'non_oak')
# ('Blueline Estate Cabernet Sauvignon', 'coffee', 12, 'non_oak')
# ('Blueline Estate Cabernet Sauvignon', 'coffee', 12, 'oak')
# ('Boal Madeira', 'coffee', 13, 'non_oak')
# ('Boal Madeira', 'coffee', 13, 'oak')
# ('Bolgheri Superiore', 'citrus', 11, 'citrus_fruit')
# ('Bolgheri Superiore', 'coffee', 178, 'non_oak')
# ('Bolgheri Superiore', 'coffee', 178, 'oak')
# ('Bolgheri Superiore', 'cream', 86, 'microbio')
# ('Bolgheri Superiore', 'toast', 50, 'microbio')
# ('Bolgheri Superiore', 'toast', 50, 'non_oak')
# ('Bolgheri Superiore Sondraia', 'coffee', 35, 'non_oak')
# ('Bolgheri Superiore Sondraia', 'coffee', 35, 'oak')
# ('Bramare Malbec Uco Valley', 'coffee', 17, 'non_oak')
# ('Bramare Malbec Uco Valley', 'coffee', 17, 'oak')
# ('Bric Dël Fiasc Barolo', 'coffee', 19, 'non_oak')
# ('Bric Dël Fiasc Barolo', 'coffee', 19, 'oak')
# ("Bricco dell'Uccellone Barbera d'Asti", 'coffee', 27, 'non_oak')
# ("Bricco dell'Uccellone Barbera d'Asti", 'coffee', 27, 'oak')
# ("Bricco dell'Uccellone Barbera d'Asti", 'cream', 12, 'microbio')
# ("Bricco dell'Uccellone Barbera d'Asti", 'toast', 11, 'microbio')
# ("Bricco dell'Uccellone Barbera d'Asti", 'toast', 11, 'non_oak')
# ('Brunello di Montalcino', 'citrus', 60, 'citrus_fruit')
# ('Brunello di Montalcino', 'coffee', 306, 'non_oak')
# ('Brunello di Montalcino', 'coffee', 306, 'oak')
# ('Brunello di Montalcino', 'cream', 93, 'microbio')
# ('Brunello di Montalcino', 'toast', 74, 'microbio')
# ('Brunello di Montalcino', 'toast', 74, 'non_oak')
# ('Brunello di Montalcino  Montosoli', 'coffee', 14, 'non_oak')
# ('Brunello di Montalcino  Montosoli', 'coffee', 14, 'oak')
# ('Brunello di Montalcino Riserva', 'coffee', 69, 'non_oak')
# ('Brunello di Montalcino Riserva', 'coffee', 69, 'oak')
# ('Brunello di Montalcino Riserva', 'cream', 15, 'microbio')
# ('Brunello di Montalcino Riserva', 'toast', 13, 'microbio')
# ('Brunello di Montalcino Riserva', 'toast', 13, 'non_oak')
# ('Brunello di Montalcino Riserva Madonna del Piano', 'coffee', 20, 'non_oak')
# ('Brunello di Montalcino Riserva Madonna del Piano', 'coffee', 20, 'oak')
# ('Brunello di Montalcino Riserva Vigna Paganelli', 'coffee', 19, 'non_oak')
# ('Brunello di Montalcino Riserva Vigna Paganelli', 'coffee', 19, 'oak')
# ('Brut Champagne', 'citrus', 2596, 'citrus_fruit')
# ('Brut Champagne', 'coffee', 145, 'non_oak')
# ('Brut Champagne', 'coffee', 145, 'oak')
# ('Brut Champagne', 'cream', 1564, 'microbio')
# ('Brut Champagne', 'green apple', 893, 'tree_fruit')
# ('Brut Champagne', 'toast', 2165, 'microbio')
# ('Brut Champagne', 'toast', 2165, 'non_oak')
# ('Brut Champagne (Gold)', 'citrus', 74, 'citrus_fruit')
# ('Brut Champagne (Gold)', 'cream', 54, 'microbio')
# ('Brut Champagne (Gold)', 'green apple', 28, 'tree_fruit')
# ('Brut Champagne (Gold)', 'toast', 20, 'microbio')
# ('Brut Champagne (Gold)', 'toast', 20, 'non_oak')
# ('Brut Cuvée Champagne Rosé', 'citrus', 436, 'citrus_fruit')
# ('Brut Cuvée Champagne Rosé', 'cream', 378, 'microbio')
# ('Brut Cuvée Champagne Rosé', 'green apple', 66, 'tree_fruit')
# ('Brut Cuvée Champagne Rosé', 'toast', 251, 'microbio')
# ('Brut Cuvée Champagne Rosé', 'toast', 251, 'non_oak')
# ('Brut Rosé Champagne', 'citrus', 763, 'citrus_fruit')
# ('Brut Rosé Champagne', 'cream', 740, 'microbio')
# ('Brut Rosé Champagne', 'green apple', 130, 'tree_fruit')
# ('Brut Rosé Champagne', 'toast', 459, 'microbio')
# ('Brut Rosé Champagne', 'toast', 459, 'non_oak')
# ('Buisson Renard', 'citrus', 45, 'citrus_fruit')
# ('Buisson Renard', 'cream', 13, 'microbio')
# ('Buisson Renard', 'green apple', 16, 'tree_fruit')
# ('Bâtard-Montrachet Grand Cru', 'citrus', 49, 'citrus_fruit')
# ('Bâtard-Montrachet Grand Cru', 'cream', 31, 'microbio')
# ('CASK 23 Cabernet Sauvignon', 'coffee', 27, 'non_oak')
# ('CASK 23 Cabernet Sauvignon', 'coffee', 27, 'oak')
# ('CASK 23 Cabernet Sauvignon', 'cream', 11, 'microbio')
# ('Cabernet Sauvignon', 'citrus', 19, 'citrus_fruit')
# ('Cabernet Sauvignon', 'coffee', 311, 'non_oak')
# ('Cabernet Sauvignon', 'coffee', 311, 'oak')
# ('Cabernet Sauvignon', 'cream', 334, 'microbio')
# ('Cabernet Sauvignon', 'toast', 121, 'microbio')
# ('Cabernet Sauvignon', 'toast', 121, 'non_oak')
# ('Cabernet Sauvignon (Signature)', 'coffee', 41, 'non_oak')
# ('Cabernet Sauvignon (Signature)', 'coffee', 41, 'oak')
# ('Cabernet Sauvignon (Signature)', 'cream', 17, 'microbio')
# ('Calcarole Amarone della Valpolicella Classico', 'coffee', 25, 'non_oak')
# ('Calcarole Amarone della Valpolicella Classico', 'coffee', 25, 'oak')
# ('Campo Inferi Amarone della Valpolicella Classico Riserva', 'coffee', 17, 'non_oak')
# ('Campo Inferi Amarone della Valpolicella Classico Riserva', 'coffee', 17, 'oak')
# ('Campo León Amarone della Valpolicella', 'coffee', 16, 'non_oak')
# ('Campo León Amarone della Valpolicella', 'coffee', 16, 'oak')
# ('Campo dei Gigli Amarone della Valpolicella', 'coffee', 15, 'non_oak')
# ('Campo dei Gigli Amarone della Valpolicella', 'coffee', 15, 'oak')
# ('Campo del Titari Amarone della Valpolicella Classico Riserva', 'coffee', 19, 'non_oak')
# ('Campo del Titari Amarone della Valpolicella Classico Riserva', 'coffee', 19, 'oak')
# ('Campolongo di Torbe Amarone della Valpolicella Classico', 'coffee', 24, 'non_oak')
# ('Campolongo di Torbe Amarone della Valpolicella Classico', 'coffee', 24, 'oak')
# ('Capellanía Reserva', 'citrus', 157, 'citrus_fruit')
# ('Capellanía Reserva', 'cream', 131, 'microbio')
# ('Capellanía Reserva', 'green apple', 31, 'tree_fruit')
# ('Capellanía Reserva', 'toast', 57, 'microbio')
# ('Capellanía Reserva', 'toast', 57, 'non_oak')
# ('Capitel Monte Olmi Amarone della Valpolicella Classico Riserva', 'coffee', 16, 'non_oak')
# ('Capitel Monte Olmi Amarone della Valpolicella Classico Riserva', 'coffee', 16, 'oak')
# ('Carruades de Lafite Pauillac', 'cream', 11, 'microbio')
# ('Castello della Sala Cervaro della Sala', 'citrus', 486, 'citrus_fruit')
# ('Castello della Sala Cervaro della Sala', 'cream', 268, 'microbio')
# ('Castello della Sala Cervaro della Sala', 'green apple', 72, 'tree_fruit')
# ('Castello della Sala Cervaro della Sala', 'toast', 78, 'microbio')
# ('Castello della Sala Cervaro della Sala', 'toast', 78, 'non_oak')
# ('Castello della Sala Muffato della Sala', 'citrus', 31, 'citrus_fruit')
# ('Castello della Sala Muffato della Sala', 'cream', 11, 'microbio')
# ('Castillo Ygay Gran Reserva Especial Tinto', 'coffee', 60, 'non_oak')
# ('Castillo Ygay Gran Reserva Especial Tinto', 'coffee', 60, 'oak')
# ('Castillo Ygay Gran Reserva Especial Tinto', 'cream', 71, 'microbio')
# ('Castillo Ygay Gran Reserva Especial Tinto', 'toast', 34, 'microbio')
# ('Castillo Ygay Gran Reserva Especial Tinto', 'toast', 34, 'non_oak')
# ('Cava Celler Batlle', 'citrus', 26, 'citrus_fruit')
# ('Cava Celler Batlle', 'cream', 25, 'microbio')
# ('Cava Celler Batlle', 'green apple', 15, 'tree_fruit')
# ('Cava Celler Batlle', 'toast', 30, 'microbio')
# ('Cava Celler Batlle', 'toast', 30, 'non_oak')
# ('Ca’ del Merlo Rosso Veneto', 'coffee', 13, 'non_oak')
# ('Ca’ del Merlo Rosso Veneto', 'coffee', 13, 'oak')
# ('Cepparello Red', 'coffee', 45, 'non_oak')
# ('Cepparello Red', 'coffee', 45, 'oak')
# ('Cepparello Red', 'cream', 16, 'microbio')
# ('Cepparello Red', 'toast', 11, 'microbio')
# ('Cepparello Red', 'toast', 11, 'non_oak')
# ('Cerretalto Brunello di Montalcino', 'coffee', 18, 'non_oak')
# ('Cerretalto Brunello di Montalcino', 'coffee', 18, 'oak')
# ("Chablis Grand Cru 'Valmur'", 'citrus', 41, 'citrus_fruit')
# ("Chablis Grand Cru 'Valmur'", 'cream', 15, 'microbio')
# ("Chablis Grand Cru 'Valmur'", 'green apple', 11, 'tree_fruit')
# ('Champagne', 'citrus', 15, 'citrus_fruit')
# ('Champagne', 'cream', 17, 'microbio')
# ('Chardonnay', 'citrus', 714, 'citrus_fruit')
# ('Chardonnay', 'cream', 362, 'microbio')
# ('Chardonnay', 'green apple', 421, 'tree_fruit')
# ('Chardonnay', 'toast', 105, 'microbio')
# ('Chardonnay', 'toast', 105, 'non_oak')
# ('Chassagne-Montrachet', 'citrus', 89, 'citrus_fruit')
# ('Chassagne-Montrachet', 'cream', 45, 'microbio')
# ('Chassagne-Montrachet', 'toast', 14, 'microbio')
# ('Chassagne-Montrachet', 'toast', 14, 'non_oak')
# ("Chassagne-Montrachet 1er Cru 'La Maltroie'", 'citrus', 26, 'citrus_fruit')
# ("Chassagne-Montrachet 1er Cru 'La Maltroie'", 'cream', 19, 'microbio')
# ("Chassagne-Montrachet Premier Cru 'Morgeot' Blanc", 'citrus', 21, 'citrus_fruit')
# ("Chassagne-Montrachet Premier Cru 'Morgeot' Blanc", 'cream', 14, 'microbio')
# ('Chassagne-Montrachet Premier Cru Morgeot Marquis de Laguiche ', 'citrus', 27, 'citrus_fruit')
# ('Chassagne-Montrachet Premier Cru Morgeot Marquis de Laguiche ', 'cream', 21, 'microbio')
# ('Chassagne-Montrachet Premier Cru Morgeot Marquis de Laguiche ', 'green apple', 13, 'tree_fruit')
# ('Chateau Buena Vista Cabernet Sauvignon Napa Valley', 'coffee', 14, 'non_oak')
# ('Chateau Buena Vista Cabernet Sauvignon Napa Valley', 'coffee', 14, 'oak')
# ('Chevalier-Montrachet Grand Cru', 'citrus', 54, 'citrus_fruit')
# ('Chevalier-Montrachet Grand Cru', 'cream', 22, 'microbio')
# ('Chevalier-Montrachet Grand Cru Blanc', 'citrus', 33, 'citrus_fruit')
# ('Chevalier-Montrachet Grand Cru Blanc', 'cream', 32, 'microbio')
# ('Chevalier-Montrachet Grand Cru Blanc', 'toast', 13, 'microbio')
# ('Chevalier-Montrachet Grand Cru Blanc', 'toast', 13, 'non_oak')
# ('Chloe Chardonnay', 'citrus', 13, 'citrus_fruit')
# ('Chloe Chardonnay', 'cream', 15, 'microbio')
# ('Château Margaux (Premier Grand Cru Classé)', 'coffee', 103, 'non_oak')
# ('Château Margaux (Premier Grand Cru Classé)', 'coffee', 103, 'oak')
# ('Château Margaux (Premier Grand Cru Classé)', 'cream', 37, 'microbio')
# ('Château Margaux (Premier Grand Cru Classé)', 'toast', 38, 'microbio')
# ('Château Margaux (Premier Grand Cru Classé)', 'toast', 38, 'non_oak')
# ('Châteauneuf-du-Pape', 'citrus', 25, 'citrus_fruit')
# ('Châteauneuf-du-Pape', 'coffee', 107, 'non_oak')
# ('Châteauneuf-du-Pape', 'coffee', 107, 'oak')
# ('Châteauneuf-du-Pape', 'cream', 63, 'microbio')
# ('Châteauneuf-du-Pape', 'toast', 53, 'microbio')
# ('Châteauneuf-du-Pape', 'toast', 53, 'non_oak')
# ('Châteauneuf-du-Pape Réservé Blanc', 'citrus', 11, 'citrus_fruit')
# ('Cinque Autoctoni Collection Limited Release', 'cream', 11, 'microbio')
# ('Cirsion Rioja', 'coffee', 16, 'non_oak')
# ('Cirsion Rioja', 'coffee', 16, 'oak')
# ('Clio', 'coffee', 105, 'non_oak')
# ('Clio', 'coffee', 105, 'oak')
# ('Clio', 'cream', 54, 'microbio')
# ('Clio', 'toast', 22, 'microbio')
# ('Clio', 'toast', 22, 'non_oak')
# ('Clos Apalta', 'coffee', 76, 'non_oak')
# ('Clos Apalta', 'coffee', 76, 'oak')
# ('Clos Apalta', 'cream', 36, 'microbio')
# ('Clos Apalta', 'toast', 13, 'microbio')
# ('Clos Apalta', 'toast', 13, 'non_oak')
# ('Clos Sainte Hune Riesling Alsace', 'citrus', 99, 'citrus_fruit')
# ('Clos Sainte Hune Riesling Alsace', 'cream', 13, 'microbio')
# ('Clos Sainte Hune Riesling Alsace', 'green apple', 36, 'tree_fruit')
# ('Clos de Tart Grand Cru Monopole', 'coffee', 13, 'non_oak')
# ('Clos de Tart Grand Cru Monopole', 'coffee', 13, 'oak')
# ('Clos de la Coulée de Serrant', 'citrus', 65, 'citrus_fruit')
# ('Clos de la Coulée de Serrant', 'cream', 45, 'microbio')
# ('Clos de la Coulée de Serrant', 'green apple', 14, 'tree_fruit')
# ('Clos de la Coulée de Serrant', 'toast', 12, 'microbio')
# ('Clos de la Coulée de Serrant', 'toast', 12, 'non_oak')
# ('Clos des Goisses Champagne', 'citrus', 78, 'citrus_fruit')
# ('Clos des Goisses Champagne', 'cream', 65, 'microbio')
# ('Clos des Goisses Champagne', 'green apple', 24, 'tree_fruit')
# ('Clos des Goisses Champagne', 'toast', 53, 'microbio')
# ('Clos des Goisses Champagne', 'toast', 53, 'non_oak')
# ('Clos des Lambrays Grand Cru', 'coffee', 28, 'non_oak')
# ('Clos des Lambrays Grand Cru', 'coffee', 28, 'oak')
# ('Clos du Mesnil', 'citrus', 62, 'citrus_fruit')
# ('Clos du Mesnil', 'cream', 16, 'microbio')
# ('Clos du Mesnil', 'green apple', 19, 'tree_fruit')
# ('Clos du Mesnil', 'toast', 33, 'microbio')
# ('Clos du Mesnil', 'toast', 33, 'non_oak')
# ('Colheita Port', 'coffee', 12, 'non_oak')
# ('Colheita Port', 'coffee', 12, 'oak')
# ('Colheita Port', 'cream', 16, 'microbio')
# ('Collection', 'citrus', 38, 'citrus_fruit')
# ('Collection', 'cream', 36, 'microbio')
# ('Collection', 'toast', 28, 'microbio')
# ('Collection', 'toast', 28, 'non_oak')
# ('Comtes de Champagne Blanc de Blancs', 'citrus', 720, 'citrus_fruit')
# ('Comtes de Champagne Blanc de Blancs', 'coffee', 39, 'non_oak')
# ('Comtes de Champagne Blanc de Blancs', 'coffee', 39, 'oak')
# ('Comtes de Champagne Blanc de Blancs', 'cream', 589, 'microbio')
# ('Comtes de Champagne Blanc de Blancs', 'green apple', 249, 'tree_fruit')
# ('Comtes de Champagne Blanc de Blancs', 'toast', 587, 'microbio')
# ('Comtes de Champagne Blanc de Blancs', 'toast', 587, 'non_oak')
# ('Conteisa Langhe', 'coffee', 13, 'non_oak')
# ('Conteisa Langhe', 'coffee', 13, 'oak')
# ('Continuum Estate', 'coffee', 36, 'non_oak')
# ('Continuum Estate', 'coffee', 36, 'oak')
# ('Continuum Estate', 'cream', 11, 'microbio')
# ('Continuum Estate', 'toast', 11, 'microbio')
# ('Continuum Estate', 'toast', 11, 'non_oak')
# ('Corton-Charlemagne Grand Cru', 'citrus', 479, 'citrus_fruit')
# ('Corton-Charlemagne Grand Cru', 'cream', 301, 'microbio')
# ('Corton-Charlemagne Grand Cru', 'green apple', 102, 'tree_fruit')
# ('Corton-Charlemagne Grand Cru', 'toast', 142, 'microbio')
# ('Corton-Charlemagne Grand Cru', 'toast', 142, 'non_oak')
# ('Corton-Charlemagne Grand Cru Blanc', 'citrus', 47, 'citrus_fruit')
# ('Corton-Charlemagne Grand Cru Blanc', 'cream', 35, 'microbio')
# ('Corton-Charlemagne Grand Cru Blanc', 'green apple', 19, 'tree_fruit')
# ('Corton-Charlemagne Grand Cru Blanc', 'toast', 20, 'microbio')
# ('Corton-Charlemagne Grand Cru Blanc', 'toast', 20, 'non_oak')
# ("Cos d'Estournel", 'coffee', 231, 'non_oak')
# ("Cos d'Estournel", 'coffee', 231, 'oak')
# ("Cos d'Estournel", 'cream', 62, 'microbio')
# ("Cos d'Estournel", 'toast', 54, 'microbio')
# ("Cos d'Estournel", 'toast', 54, 'non_oak')
# ('Cosimo Varvaglione Collezione Privata Primitivo di Manduria', 'coffee', 20, 'non_oak')
# ('Cosimo Varvaglione Collezione Privata Primitivo di Manduria', 'coffee', 20, 'oak')
# ('Costa Russi (Barbaresco) Langhe', 'coffee', 14, 'non_oak')
# ('Costa Russi (Barbaresco) Langhe', 'coffee', 14, 'oak')
# ('Costasera Amarone della Valpolicella Classico', 'coffee', 372, 'non_oak')
# ('Costasera Amarone della Valpolicella Classico', 'coffee', 372, 'oak')
# ('Costasera Amarone della Valpolicella Classico', 'cream', 49, 'microbio')
# ('Costasera Amarone della Valpolicella Classico', 'toast', 34, 'microbio')
# ('Costasera Amarone della Valpolicella Classico', 'toast', 34, 'non_oak')
# ('Coteau de Vernon Condrieu', 'citrus', 29, 'citrus_fruit')
# ('Coteau de Vernon Condrieu', 'cream', 34, 'microbio')
# ('Cream Tradición Vos 20 Years', 'cream', 22, 'microbio')
# ('Cristal Brut Champagne (Millésimé)', 'citrus', 954, 'citrus_fruit')
# ('Cristal Brut Champagne (Millésimé)', 'coffee', 26, 'non_oak')
# ('Cristal Brut Champagne (Millésimé)', 'coffee', 26, 'oak')
# ('Cristal Brut Champagne (Millésimé)', 'cream', 496, 'microbio')
# ('Cristal Brut Champagne (Millésimé)', 'green apple', 298, 'tree_fruit')
# ('Cristal Brut Champagne (Millésimé)', 'toast', 464, 'microbio')
# ('Cristal Brut Champagne (Millésimé)', 'toast', 464, 'non_oak')
# ('Cristal Rosé Brut Champagne (Millésimé)', 'citrus', 74, 'citrus_fruit')
# ('Cristal Rosé Brut Champagne (Millésimé)', 'cream', 48, 'microbio')
# ('Cristal Rosé Brut Champagne (Millésimé)', 'green apple', 15, 'tree_fruit')
# ('Cristal Rosé Brut Champagne (Millésimé)', 'toast', 51, 'microbio')
# ('Cristal Rosé Brut Champagne (Millésimé)', 'toast', 51, 'non_oak')
# ('Cuvée Annamaria Clementi (Extra Brut)', 'citrus', 35, 'citrus_fruit')
# ('Cuvée Annamaria Clementi (Extra Brut)', 'cream', 65, 'microbio')
# ('Cuvée Annamaria Clementi (Extra Brut)', 'green apple', 20, 'tree_fruit')
# ('Cuvée Annamaria Clementi (Extra Brut)', 'toast', 40, 'microbio')
# ('Cuvée Annamaria Clementi (Extra Brut)', 'toast', 40, 'non_oak')
# ('Cuvée Nicolas François Billecart Brut Champagne', 'citrus', 173, 'citrus_fruit')
# ('Cuvée Nicolas François Billecart Brut Champagne', 'cream', 134, 'microbio')
# ('Cuvée Nicolas François Billecart Brut Champagne', 'green apple', 53, 'tree_fruit')
# ('Cuvée Nicolas François Billecart Brut Champagne', 'toast', 159, 'microbio')
# ('Cuvée Nicolas François Billecart Brut Champagne', 'toast', 159, 'non_oak')
# ('Cuvée Risleus Brut Champagne Premier Cru', 'toast', 18, 'microbio')
# ('Cuvée Risleus Brut Champagne Premier Cru', 'toast', 18, 'non_oak')
# ('Cuvée des Enchanteleurs Brut Champagne', 'citrus', 25, 'citrus_fruit')
# ('Cuvée des Enchanteleurs Brut Champagne', 'coffee', 14, 'non_oak')
# ('Cuvée des Enchanteleurs Brut Champagne', 'coffee', 14, 'oak')
# ('Cuvée des Enchanteleurs Brut Champagne', 'cream', 37, 'microbio')
# ('Cuvée des Enchanteleurs Brut Champagne', 'green apple', 11, 'tree_fruit')
# ('Cuvée des Enchanteleurs Brut Champagne', 'toast', 31, 'microbio')
# ('Cuvée des Enchanteleurs Brut Champagne', 'toast', 31, 'non_oak')
# ('Côte-Rôtie', 'coffee', 26, 'non_oak')
# ('Côte-Rôtie', 'coffee', 26, 'oak')
# ('Côte-Rôtie La Landonne', 'coffee', 26, 'non_oak')
# ('Côte-Rôtie La Landonne', 'coffee', 26, 'oak')
# ('Côte-Rôtie La Mouline', 'coffee', 25, 'non_oak')
# ('Côte-Rôtie La Mouline', 'coffee', 25, 'oak')
# ('Côte-Rôtie La Turque', 'coffee', 37, 'non_oak')
# ('Côte-Rôtie La Turque', 'coffee', 37, 'oak')
# ('Côte-Rôtie La Turque', 'cream', 11, 'microbio')
# ('Côte-Rôtie La Turque', 'toast', 13, 'microbio')
# ('Côte-Rôtie La Turque', 'toast', 13, 'non_oak')
# ('Côtes de Bourg', 'coffee', 34, 'non_oak')
# ('Côtes de Bourg', 'coffee', 34, 'oak')
# ('Côtes de Bourg', 'cream', 11, 'microbio')
# ('Dagromis Barolo', 'coffee', 18, 'non_oak')
# ('Dagromis Barolo', 'coffee', 18, 'oak')
# ('Dalmau Rioja', 'coffee', 18, 'non_oak')
# ('Dalmau Rioja', 'coffee', 18, 'oak')
# ('Dalmau Rioja', 'cream', 19, 'microbio')
# ('Dalmau Rioja', 'toast', 15, 'microbio')
# ('Dalmau Rioja', 'toast', 15, 'non_oak')
# ('Dom Ruinart Blanc de Blancs Brut Champagne', 'citrus', 250, 'citrus_fruit')
# ('Dom Ruinart Blanc de Blancs Brut Champagne', 'coffee', 22, 'non_oak')
# ('Dom Ruinart Blanc de Blancs Brut Champagne', 'coffee', 22, 'oak')
# ('Dom Ruinart Blanc de Blancs Brut Champagne', 'cream', 165, 'microbio')
# ('Dom Ruinart Blanc de Blancs Brut Champagne', 'green apple', 86, 'tree_fruit')
# ('Dom Ruinart Blanc de Blancs Brut Champagne', 'toast', 226, 'microbio')
# ('Dom Ruinart Blanc de Blancs Brut Champagne', 'toast', 226, 'non_oak')
# ('Domaine des Tourettes Hermitage Rouge', 'coffee', 16, 'non_oak')
# ('Domaine des Tourettes Hermitage Rouge', 'coffee', 16, 'oak')
# ('Domaine des Tourettes Hermitage Rouge', 'cream', 15, 'microbio')
# ('Dominus (Christian Moueix)', 'coffee', 76, 'non_oak')
# ('Dominus (Christian Moueix)', 'coffee', 76, 'oak')
# ('Dominus (Christian Moueix)', 'cream', 58, 'microbio')
# ('Dominus (Christian Moueix)', 'toast', 25, 'microbio')
# ('Dominus (Christian Moueix)', 'toast', 25, 'non_oak')
# ('Domus Aurea Cabernet Sauvignon', 'coffee', 17, 'non_oak')
# ('Domus Aurea Cabernet Sauvignon', 'coffee', 17, 'oak')
# ('Don PX Convento Selección', 'coffee', 29, 'non_oak')
# ('Don PX Convento Selección', 'coffee', 29, 'oak')
# ('Douro Pintas Tinto', 'coffee', 11, 'non_oak')
# ('Douro Pintas Tinto', 'coffee', 11, 'oak')
# ('Duemani Cabernet Franc', 'coffee', 11, 'non_oak')
# ('Duemani Cabernet Franc', 'coffee', 11, 'oak')
# ('Eight Years In The Desert', 'coffee', 46, 'non_oak')
# ('Eight Years In The Desert', 'coffee', 46, 'oak')
# ('Eight Years In The Desert', 'cream', 41, 'microbio')
# ('Eight Years In The Desert', 'toast', 22, 'microbio')
# ('Eight Years In The Desert', 'toast', 22, 'non_oak')
# ('Evenstad Reserve Pinot Noir', 'coffee', 12, 'non_oak')
# ('Evenstad Reserve Pinot Noir', 'coffee', 12, 'oak')
# ('Evenstad Reserve Pinot Noir', 'cream', 27, 'microbio')
# ('Evenstad Reserve Pinot Noir', 'toast', 12, 'microbio')
# ('Evenstad Reserve Pinot Noir', 'toast', 12, 'non_oak')
# ('FAY Cabernet Sauvignon', 'coffee', 33, 'non_oak')
# ('FAY Cabernet Sauvignon', 'coffee', 33, 'oak')
# ('FAY Cabernet Sauvignon', 'cream', 12, 'microbio')
# ('Finca Altamira Malbec', 'coffee', 14, 'non_oak')
# ('Finca Altamira Malbec', 'coffee', 14, 'oak')
# ('Finca Altamira Malbec', 'cream', 13, 'microbio')
# ('Flaccianello della Pieve', 'coffee', 78, 'non_oak')
# ('Flaccianello della Pieve', 'coffee', 78, 'oak')
# ('Flaccianello della Pieve', 'cream', 22, 'microbio')
# ('Flaccianello della Pieve', 'toast', 25, 'microbio')
# ('Flaccianello della Pieve', 'toast', 25, 'non_oak')
# ('Flor de Pingus', 'coffee', 79, 'non_oak')
# ('Flor de Pingus', 'coffee', 79, 'oak')
# ('Flor de Pingus', 'cream', 25, 'microbio')
# ('Flor de Pingus', 'toast', 26, 'microbio')
# ('Flor de Pingus', 'toast', 26, 'non_oak')
# ('Fusion V', 'coffee', 57, 'non_oak')
# ('Fusion V', 'coffee', 57, 'oak')
# ('Gaia & Rey Langhe', 'citrus', 69, 'citrus_fruit')
# ('Gaia & Rey Langhe', 'cream', 53, 'microbio')
# ('Gaia & Rey Langhe', 'green apple', 20, 'tree_fruit')
# ('Gaia & Rey Langhe', 'toast', 17, 'microbio')
# ('Gaia & Rey Langhe', 'toast', 17, 'non_oak')
# ('Galatrona', 'coffee', 37, 'non_oak')
# ('Galatrona', 'coffee', 37, 'oak')
# ('Galatrona', 'cream', 19, 'microbio')
# ('Gaudium', 'coffee', 32, 'non_oak')
# ('Gaudium', 'coffee', 32, 'oak')
# ('Gaudium', 'cream', 11, 'microbio')
# ('Gaudium', 'toast', 11, 'microbio')
# ('Gaudium', 'toast', 11, 'non_oak')
# ('Georges De Latour Private Reserve Cabernet Sauvignon', 'coffee', 30, 'non_oak')
# ('Georges De Latour Private Reserve Cabernet Sauvignon', 'coffee', 30, 'oak')
# ('Georges De Latour Private Reserve Cabernet Sauvignon', 'cream', 15, 'microbio')
# ('Georges De Latour Private Reserve Cabernet Sauvignon', 'toast', 23, 'microbio')
# ('Georges De Latour Private Reserve Cabernet Sauvignon', 'toast', 23, 'non_oak')
# ('Gewürztraminer Lunare', 'citrus', 17, 'citrus_fruit')
# ("Giallo d'Arles Greco di Tufo", 'citrus', 34, 'citrus_fruit')
# ('Giramonte Toscana', 'coffee', 17, 'non_oak')
# ('Giramonte Toscana', 'coffee', 17, 'oak')
# ('Gold Series Syrah', 'coffee', 14, 'non_oak')
# ('Gold Series Syrah', 'coffee', 14, 'oak')
# ('Gorgona', 'cream', 12, 'microbio')
# ('Gran Enemigo', 'coffee', 18, 'non_oak')
# ('Gran Enemigo', 'coffee', 18, 'oak')
# ('Gran Reserva 890', 'coffee', 25, 'non_oak')
# ('Gran Reserva 890', 'coffee', 25, 'oak')
# ('Gran Reserva 890', 'cream', 42, 'microbio')
# ('Gran Reserva 890', 'toast', 26, 'microbio')
# ('Gran Reserva 890', 'toast', 26, 'non_oak')
# ('Gran Reserva Rioja (Finca Ygay)', 'coffee', 17, 'non_oak')
# ('Gran Reserva Rioja (Finca Ygay)', 'coffee', 17, 'oak')
# ('Grand Siècle Champagne (Grande Cuvée)', 'citrus', 296, 'citrus_fruit')
# ('Grand Siècle Champagne (Grande Cuvée)', 'cream', 169, 'microbio')
# ('Grand Siècle Champagne (Grande Cuvée)', 'green apple', 136, 'tree_fruit')
# ('Grand Siècle Champagne (Grande Cuvée)', 'toast', 212, 'microbio')
# ('Grand Siècle Champagne (Grande Cuvée)', 'toast', 212, 'non_oak')
# ('Grand Vin Pauillac (Premier Grand Cru Classé)', 'coffee', 108, 'non_oak')
# ('Grand Vin Pauillac (Premier Grand Cru Classé)', 'coffee', 108, 'oak')
# ('Grand Vin Pauillac (Premier Grand Cru Classé)', 'cream', 29, 'microbio')
# ('Grand Vin Pauillac (Premier Grand Cru Classé)', 'toast', 23, 'microbio')
# ('Grand Vin Pauillac (Premier Grand Cru Classé)', 'toast', 23, 'non_oak')
# ('Grand Vin de Château Palmer (Grand Cru Classé)', 'coffee', 111, 'non_oak')
# ('Grand Vin de Château Palmer (Grand Cru Classé)', 'coffee', 111, 'oak')
# ('Grand Vin de Château Palmer (Grand Cru Classé)', 'cream', 38, 'microbio')
# ('Grand Vin de Château Palmer (Grand Cru Classé)', 'toast', 35, 'microbio')
# ('Grand Vin de Château Palmer (Grand Cru Classé)', 'toast', 35, 'non_oak')
# ('Grande Cuvée', 'citrus', 916, 'citrus_fruit')
# ('Grande Cuvée', 'coffee', 50, 'non_oak')
# ('Grande Cuvée', 'coffee', 50, 'oak')
# ('Grande Cuvée', 'cream', 439, 'microbio')
# ('Grande Cuvée', 'green apple', 304, 'tree_fruit')
# ('Grande Cuvée', 'toast', 713, 'microbio')
# ('Grande Cuvée', 'toast', 713, 'non_oak')
# ('Grange', 'coffee', 129, 'non_oak')
# ('Grange', 'coffee', 129, 'oak')
# ('Grange', 'cream', 44, 'microbio')
# ('Grange', 'toast', 33, 'microbio')
# ('Grange', 'toast', 33, 'non_oak')
# ('Guerriero del Mare', 'citrus', 63, 'citrus_fruit')
# ('Guerriero del Mare', 'cream', 17, 'microbio')
# ('Guerriero della Terra', 'coffee', 12, 'non_oak')
# ('Guerriero della Terra', 'coffee', 12, 'oak')
# ('Guerriero della Terra', 'cream', 12, 'microbio')
# ('Harlan Estate Red', 'coffee', 27, 'non_oak')
# ('Harlan Estate Red', 'coffee', 27, 'oak')
# ('Harlan Estate Red', 'cream', 20, 'microbio')
# ('Hermitage La Chapelle Rouge', 'coffee', 60, 'non_oak')
# ('Hermitage La Chapelle Rouge', 'coffee', 60, 'oak')
# ('Hermitage La Chapelle Rouge', 'cream', 22, 'microbio')
# ('Hermitage La Chapelle Rouge', 'toast', 18, 'microbio')
# ('Hermitage La Chapelle Rouge', 'toast', 18, 'non_oak')
# ('Hommage à Jacques Perrin Châteauneuf-du-Pape', 'coffee', 12, 'non_oak')
# ('Hommage à Jacques Perrin Châteauneuf-du-Pape', 'coffee', 12, 'oak')
# ('Howell Mountain Cabernet Sauvignon', 'coffee', 22, 'non_oak')
# ('Howell Mountain Cabernet Sauvignon', 'coffee', 22, 'oak')
# ('Hyde Vineyard Chardonnay', 'citrus', 17, 'citrus_fruit')
# ('Il Bricco Barbaresco', 'coffee', 15, 'non_oak')
# ('Il Bricco Barbaresco', 'coffee', 15, 'oak')
# ('Il Pino di Biserno', 'coffee', 31, 'non_oak')
# ('Il Pino di Biserno', 'coffee', 31, 'oak')
# ('Il Pino di Biserno', 'cream', 19, 'microbio')
# ('Il San Lorenzo Bianco', 'cream', 13, 'microbio')
# ('Insignia', 'coffee', 97, 'non_oak')
# ('Insignia', 'coffee', 97, 'oak')
# ('Insignia', 'cream', 51, 'microbio')
# ('Insignia', 'toast', 29, 'microbio')
# ('Insignia', 'toast', 29, 'non_oak')
# ('Isosceles', 'coffee', 32, 'non_oak')
# ('Isosceles', 'coffee', 32, 'oak')
# ('Isosceles', 'cream', 16, 'microbio')
# ('Isosceles', 'toast', 20, 'microbio')
# ('Isosceles', 'toast', 20, 'non_oak')
# ('Kairos', 'coffee', 12, 'non_oak')
# ('Kairos', 'coffee', 12, 'oak')
# ('Kevin Arnold Shiraz', 'coffee', 12, 'non_oak')
# ('Kevin Arnold Shiraz', 'coffee', 12, 'oak')
# ('Kurni Marche', 'coffee', 20, 'non_oak')
# ('Kurni Marche', 'coffee', 20, 'oak')
# ("L'Apparita", 'coffee', 22, 'non_oak')
# ("L'Apparita", 'coffee', 22, 'oak')
# ("L'Hermitage", 'coffee', 18, 'non_oak')
# ("L'Hermitage", 'coffee', 18, 'oak')
# ('La Chapelle de La Mission Haut-Brion Pessac-Léognan', 'coffee', 32, 'non_oak')
# ('La Chapelle de La Mission Haut-Brion Pessac-Léognan', 'coffee', 32, 'oak')
# ('La Cueva del Contador Rioja', 'coffee', 13, 'non_oak')
# ('La Cueva del Contador Rioja', 'coffee', 13, 'oak')
# ('La Grande Année Brut Champagne', 'citrus', 454, 'citrus_fruit')
# ('La Grande Année Brut Champagne', 'coffee', 32, 'non_oak')
# ('La Grande Année Brut Champagne', 'coffee', 32, 'oak')
# ('La Grande Année Brut Champagne', 'cream', 425, 'microbio')
# ('La Grande Année Brut Champagne', 'green apple', 175, 'tree_fruit')
# ('La Grande Année Brut Champagne', 'toast', 525, 'microbio')
# ('La Grande Année Brut Champagne', 'toast', 525, 'non_oak')
# ('La Grande Dame Brut Champagne', 'citrus', 326, 'citrus_fruit')
# ('La Grande Dame Brut Champagne', 'coffee', 16, 'non_oak')
# ('La Grande Dame Brut Champagne', 'coffee', 16, 'oak')
# ('La Grande Dame Brut Champagne', 'cream', 178, 'microbio')
# ('La Grande Dame Brut Champagne', 'green apple', 111, 'tree_fruit')
# ('La Grande Dame Brut Champagne', 'toast', 244, 'microbio')
# ('La Grande Dame Brut Champagne', 'toast', 244, 'non_oak')
# ('La Grande Dame Brut Rosé Champagne', 'citrus', 11, 'citrus_fruit')
# ('La Grande Dame Brut Rosé Champagne', 'cream', 13, 'microbio')
# ('La Grande Dame Brut Rosé Champagne', 'toast', 15, 'microbio')
# ('La Grande Dame Brut Rosé Champagne', 'toast', 15, 'non_oak')
# ('La Joie', 'coffee', 14, 'non_oak')
# ('La Joie', 'coffee', 14, 'oak')
# ('La Piu Belle', 'coffee', 22, 'non_oak')
# ('La Piu Belle', 'coffee', 22, 'oak')
# ('La Piu Belle', 'cream', 14, 'microbio')
# ('Lagrein Riserva Porphyr', 'coffee', 15, 'non_oak')
# ('Lagrein Riserva Porphyr', 'coffee', 15, 'oak')
# ('Le Désir', 'coffee', 11, 'non_oak')
# ('Le Désir', 'coffee', 11, 'oak')
# ('Le Mesnil Blanc de Blancs (Cuvée S) Brut Champagne', 'citrus', 240, 'citrus_fruit')
# ('Le Mesnil Blanc de Blancs (Cuvée S) Brut Champagne', 'coffee', 12, 'non_oak')
# ('Le Mesnil Blanc de Blancs (Cuvée S) Brut Champagne', 'coffee', 12, 'oak')
# ('Le Mesnil Blanc de Blancs (Cuvée S) Brut Champagne', 'cream', 118, 'microbio')
# ('Le Mesnil Blanc de Blancs (Cuvée S) Brut Champagne', 'green apple', 76, 'tree_fruit')
# ('Le Mesnil Blanc de Blancs (Cuvée S) Brut Champagne', 'toast', 100, 'microbio')
# ('Le Mesnil Blanc de Blancs (Cuvée S) Brut Champagne', 'toast', 100, 'non_oak')
# ('Le Petit Cheval Bordeaux Blanc', 'citrus', 28, 'citrus_fruit')
# ('Le Petit Cheval Bordeaux Blanc', 'cream', 15, 'microbio')
# ('Le Petit Mouton de Mouton Rothschild Pauillac', 'coffee', 17, 'non_oak')
# ('Le Petit Mouton de Mouton Rothschild Pauillac', 'coffee', 17, 'oak')
# ('Le Serre Nuove', 'coffee', 101, 'non_oak')
# ('Le Serre Nuove', 'coffee', 101, 'oak')
# ('Le Serre Nuove', 'cream', 56, 'microbio')
# ('Le Serre Nuove', 'toast', 24, 'microbio')
# ('Le Serre Nuove', 'toast', 24, 'non_oak')
# ('Les Blanchiens Brut Nature Champagne Premier Cru', 'citrus', 11, 'citrus_fruit')
# ('Les Blanchiens Brut Nature Champagne Premier Cru', 'toast', 12, 'microbio')
# ('Les Blanchiens Brut Nature Champagne Premier Cru', 'toast', 12, 'non_oak')
# ('Les Clos Chablís Grand Cru', 'citrus', 50, 'citrus_fruit')
# ('Les Clos Chablís Grand Cru', 'cream', 23, 'microbio')
# ('Les Clos Chablís Grand Cru', 'green apple', 11, 'tree_fruit')
# ('Les Noisetiers', 'citrus', 174, 'citrus_fruit')
# ('Les Noisetiers', 'cream', 197, 'microbio')
# ('Les Noisetiers', 'green apple', 44, 'tree_fruit')
# ('Les Noisetiers', 'toast', 37, 'microbio')
# ('Les Noisetiers', 'toast', 37, 'non_oak')
# ('Les Pavots', 'coffee', 17, 'non_oak')
# ('Les Pavots', 'coffee', 17, 'oak')
# ('Les Pavots', 'cream', 13, 'microbio')
# ('Limited Edition 10 Vendemmie', 'coffee', 45, 'non_oak')
# ('Limited Edition 10 Vendemmie', 'coffee', 45, 'oak')
# ('Limited Edition 10 Vendemmie', 'cream', 15, 'microbio')
# ('Lion Tamer Napa Valley Red Blend', 'cream', 16, 'microbio')
# ('Luce', 'coffee', 54, 'non_oak')
# ('Luce', 'coffee', 54, 'oak')
# ('Luce', 'cream', 15, 'microbio')
# ('Luce', 'toast', 15, 'microbio')
# ('Luce', 'toast', 15, 'non_oak')
# ('Luce Brunello di Montalcino', 'coffee', 12, 'non_oak')
# ('Luce Brunello di Montalcino', 'coffee', 12, 'oak')
# ('Lupi Rezerva', 'coffee', 39, 'non_oak')
# ('Lupi Rezerva', 'coffee', 39, 'oak')
# ('Lupicaia', 'coffee', 14, 'non_oak')
# ('Lupicaia', 'coffee', 14, 'oak')
# ('MV', 'citrus', 131, 'citrus_fruit')
# ('MV', 'cream', 109, 'microbio')
# ('MV', 'green apple', 33, 'tree_fruit')
# ('MV', 'toast', 113, 'microbio')
# ('MV', 'toast', 113, 'non_oak')
# ('Macán', 'coffee', 41, 'non_oak')
# ('Macán', 'coffee', 41, 'oak')
# ('Macán', 'cream', 14, 'microbio')
# ('Macán Clásico', 'coffee', 52, 'non_oak')
# ('Macán Clásico', 'coffee', 52, 'oak')
# ('Macán Clásico', 'cream', 11, 'microbio')
# ('Macán Clásico', 'toast', 15, 'microbio')
# ('Macán Clásico', 'toast', 15, 'non_oak')
# ('Mai The First A.Montes Malbec', 'coffee', 23, 'non_oak')
# ('Mai The First A.Montes Malbec', 'coffee', 23, 'oak')
# ('Malbec', 'coffee', 13, 'non_oak')
# ('Malbec', 'coffee', 13, 'oak')
# ('Malbec Argentino', 'coffee', 45, 'non_oak')
# ('Malbec Argentino', 'coffee', 45, 'oak')
# ('Malbec Argentino', 'cream', 13, 'microbio')
# ('Malbec Argentino', 'toast', 14, 'microbio')
# ('Malbec Argentino', 'toast', 14, 'non_oak')
# ('Malleolus', 'coffee', 86, 'non_oak')
# ('Malleolus', 'coffee', 86, 'oak')
# ('Malleolus', 'cream', 12, 'microbio')
# ('Malleolus', 'toast', 26, 'microbio')
# ('Malleolus', 'toast', 26, 'non_oak')
# ('Malleolus de Sanchomartin', 'coffee', 20, 'non_oak')
# ('Malleolus de Sanchomartin', 'coffee', 20, 'oak')
# ('Margaux (Grand Cru Classé)', 'coffee', 77, 'non_oak')
# ('Margaux (Grand Cru Classé)', 'coffee', 77, 'oak')
# ('Margaux (Grand Cru Classé)', 'cream', 22, 'microbio')
# ('Margaux (Grand Cru Classé)', 'toast', 26, 'microbio')
# ('Margaux (Grand Cru Classé)', 'toast', 26, 'non_oak')
# ('Mazzano Amarone Della Valpolicella Classico', 'coffee', 18, 'non_oak')
# ('Mazzano Amarone Della Valpolicella Classico', 'coffee', 18, 'oak')
# ('Mendoza', 'coffee', 64, 'non_oak')
# ('Mendoza', 'coffee', 64, 'oak')
# ('Mendoza', 'cream', 23, 'microbio')
# ('Messorio', 'coffee', 40, 'non_oak')
# ('Messorio', 'coffee', 40, 'oak')
# ("Meursault 1er Cru 'Les Genevrières'", 'citrus', 13, 'citrus_fruit')
# ('Mille E Una Notte', 'coffee', 22, 'non_oak')
# ('Mille E Una Notte', 'coffee', 22, 'oak')
# ('Mille E Una Notte', 'cream', 11, 'microbio')
# ('Monte Bello', 'coffee', 53, 'non_oak')
# ('Monte Bello', 'coffee', 53, 'oak')
# ('Monte Bello', 'cream', 27, 'microbio')
# ('Monte Bello', 'toast', 15, 'microbio')
# ('Monte Bello', 'toast', 15, 'non_oak')
# ("Montepulciano d'Abruzzo", 'coffee', 28, 'non_oak')
# ("Montepulciano d'Abruzzo", 'coffee', 28, 'oak')
# ('Montrachet Grand Cru', 'citrus', 38, 'citrus_fruit')
# ('Montrachet Grand Cru', 'cream', 22, 'microbio')
# ('Montrachet Grand Cru Blanc', 'citrus', 15, 'citrus_fruit')
# ('Montrachet Grand Cru Marquis de Laguiche', 'citrus', 41, 'citrus_fruit')
# ('Montrachet Grand Cru Marquis de Laguiche', 'cream', 27, 'microbio')
# ('Mossone', 'coffee', 16, 'non_oak')
# ('Mossone', 'coffee', 16, 'oak')
# ('N.P.U. Extra Brut Champagne (Nec Plus Ultra)', 'citrus', 30, 'citrus_fruit')
# ('N.P.U. Extra Brut Champagne (Nec Plus Ultra)', 'cream', 19, 'microbio')
# ('N.P.U. Extra Brut Champagne (Nec Plus Ultra)', 'toast', 30, 'microbio')
# ('N.P.U. Extra Brut Champagne (Nec Plus Ultra)', 'toast', 30, 'non_oak')
# ('Nicolás Catena Zapata', 'coffee', 43, 'non_oak')
# ('Nicolás Catena Zapata', 'coffee', 43, 'oak')
# ('Nicolás Catena Zapata', 'cream', 24, 'microbio')
# ('Nine Popes', 'coffee', 11, 'non_oak')
# ('Nine Popes', 'coffee', 11, 'oak')
# ('Nine Popes', 'toast', 14, 'microbio')
# ('Nine Popes', 'toast', 14, 'non_oak')
# ('Nosotros Single Vineyard Nómade', 'toast', 14, 'microbio')
# ('Nosotros Single Vineyard Nómade', 'toast', 14, 'non_oak')
# ('Nuits-Saint-Georges 1er Cru Les Damodes', 'toast', 13, 'microbio')
# ('Nuits-Saint-Georges 1er Cru Les Damodes', 'toast', 13, 'non_oak')
# ('One Point Five Cabernet Sauvignon', 'coffee', 40, 'non_oak')
# ('One Point Five Cabernet Sauvignon', 'coffee', 40, 'oak')
# ('One Point Five Cabernet Sauvignon', 'cream', 28, 'microbio')
# ('One Sixteen Chardonnay', 'citrus', 76, 'citrus_fruit')
# ('One Sixteen Chardonnay', 'cream', 17, 'microbio')
# ('One Sixteen Chardonnay', 'green apple', 43, 'tree_fruit')
# ('One Sixteen Chardonnay', 'toast', 16, 'microbio')
# ('One Sixteen Chardonnay', 'toast', 16, 'non_oak')
# ('Opus One', 'coffee', 149, 'non_oak')
# ('Opus One', 'coffee', 149, 'oak')
# ('Opus One', 'cream', 119, 'microbio')
# ('Opus One', 'toast', 55, 'microbio')
# ('Opus One', 'toast', 55, 'non_oak')
# ('Oreno Toscana', 'coffee', 52, 'non_oak')
# ('Oreno Toscana', 'coffee', 52, 'oak')
# ('Oreno Toscana', 'cream', 21, 'microbio')
# ('Oreno Toscana', 'toast', 18, 'microbio')
# ('Oreno Toscana', 'toast', 18, 'non_oak')
# ('Overture', 'coffee', 34, 'non_oak')
# ('Overture', 'coffee', 34, 'oak')
# ('Overture', 'cream', 12, 'microbio')
# ('P2 Plénitude Brut Champagne', 'citrus', 141, 'citrus_fruit')
# ('P2 Plénitude Brut Champagne', 'coffee', 14, 'non_oak')
# ('P2 Plénitude Brut Champagne', 'coffee', 14, 'oak')
# ('P2 Plénitude Brut Champagne', 'cream', 135, 'microbio')
# ('P2 Plénitude Brut Champagne', 'green apple', 30, 'tree_fruit')
# ('P2 Plénitude Brut Champagne', 'toast', 161, 'microbio')
# ('P2 Plénitude Brut Champagne', 'toast', 161, 'non_oak')
# ('Paleo Rosso', 'coffee', 62, 'non_oak')
# ('Paleo Rosso', 'coffee', 62, 'oak')
# ('Paleo Rosso', 'cream', 27, 'microbio')
# ('Papillon', 'coffee', 61, 'non_oak')
# ('Papillon', 'coffee', 61, 'oak')
# ('Papillon', 'cream', 29, 'microbio')
# ('Papillon', 'toast', 38, 'microbio')
# ('Papillon', 'toast', 38, 'non_oak')
# ('Pauillac (Grand Cru Classé)', 'citrus', 29, 'citrus_fruit')
# ('Pauillac (Grand Cru Classé)', 'coffee', 659, 'non_oak')
# ('Pauillac (Grand Cru Classé)', 'coffee', 659, 'oak')
# ('Pauillac (Grand Cru Classé)', 'cream', 189, 'microbio')
# ('Pauillac (Grand Cru Classé)', 'toast', 171, 'microbio')
# ('Pauillac (Grand Cru Classé)', 'toast', 171, 'non_oak')
# ('Pauillac (Premier Grand Cru Classé)', 'citrus', 17, 'citrus_fruit')
# ('Pauillac (Premier Grand Cru Classé)', 'coffee', 385, 'non_oak')
# ('Pauillac (Premier Grand Cru Classé)', 'coffee', 385, 'oak')
# ('Pauillac (Premier Grand Cru Classé)', 'cream', 105, 'microbio')
# ('Pauillac (Premier Grand Cru Classé)', 'toast', 90, 'microbio')
# ('Pauillac (Premier Grand Cru Classé)', 'toast', 90, 'non_oak')
# ('Pavillon Rouge du Château Margaux', 'coffee', 35, 'non_oak')
# ('Pavillon Rouge du Château Margaux', 'coffee', 35, 'oak')
# ('Pavillon Rouge du Château Margaux', 'cream', 19, 'microbio')
# ('Pavillon Rouge du Château Margaux', 'toast', 13, 'microbio')
# ('Pavillon Rouge du Château Margaux', 'toast', 13, 'non_oak')
# ('Pedro Ximenez Tradición 20 Years Old Vos', 'coffee', 23, 'non_oak')
# ('Pedro Ximenez Tradición 20 Years Old Vos', 'coffee', 23, 'oak')
# ('Percarlo', 'coffee', 14, 'non_oak')
# ('Percarlo', 'coffee', 14, 'oak')
# ('Perpetual', 'coffee', 12, 'non_oak')
# ('Perpetual', 'coffee', 12, 'oak')
# ('Pessac-Léognan (Grand Cru Classé de Graves)', 'citrus', 64, 'citrus_fruit')
# ('Pessac-Léognan (Grand Cru Classé de Graves)', 'coffee', 265, 'non_oak')
# ('Pessac-Léognan (Grand Cru Classé de Graves)', 'coffee', 265, 'oak')
# ('Pessac-Léognan (Grand Cru Classé de Graves)', 'cream', 143, 'microbio')
# ('Pessac-Léognan (Grand Cru Classé de Graves)', 'green apple', 12, 'tree_fruit')
# ('Pessac-Léognan (Grand Cru Classé de Graves)', 'toast', 81, 'microbio')
# ('Pessac-Léognan (Grand Cru Classé de Graves)', 'toast', 81, 'non_oak')
# ('Pessac-Léognan (Premier Grand Cru Classé)', 'coffee', 129, 'non_oak')
# ('Pessac-Léognan (Premier Grand Cru Classé)', 'coffee', 129, 'oak')
# ('Pessac-Léognan (Premier Grand Cru Classé)', 'cream', 38, 'microbio')
# ('Pessac-Léognan (Premier Grand Cru Classé)', 'toast', 38, 'microbio')
# ('Pessac-Léognan (Premier Grand Cru Classé)', 'toast', 38, 'non_oak')
# ('Pessac-Léognan Blanc (Grand Cru Classé de Graves)', 'citrus', 58, 'citrus_fruit')
# ('Pessac-Léognan Blanc (Grand Cru Classé de Graves)', 'cream', 21, 'microbio')
# ('Pessac-Léognan Blanc (Grand Cru Classé de Graves)', 'toast', 16, 'microbio')
# ('Pessac-Léognan Blanc (Grand Cru Classé de Graves)', 'toast', 16, 'non_oak')
# ('Pian delle Vigne Brunello di Montalcino', 'coffee', 70, 'non_oak')
# ('Pian delle Vigne Brunello di Montalcino', 'coffee', 70, 'oak')
# ('Pian delle Vigne Brunello di Montalcino', 'cream', 26, 'microbio')
# ('Pian delle Vigne Brunello di Montalcino', 'toast', 11, 'microbio')
# ('Pian delle Vigne Brunello di Montalcino', 'toast', 11, 'non_oak')
# ('Pietro Dal Cero Amarone della Valpolicella', 'coffee', 13, 'non_oak')
# ('Pietro Dal Cero Amarone della Valpolicella', 'coffee', 13, 'oak')
# ('Pieve Santa Restituta Brunello di Montalcino', 'coffee', 44, 'non_oak')
# ('Pieve Santa Restituta Brunello di Montalcino', 'coffee', 44, 'oak')
# ('Pieve Santa Restituta Brunello di Montalcino', 'cream', 15, 'microbio')
# ('Pieve Santa Restituta Brunello di Montalcino', 'toast', 15, 'microbio')
# ('Pieve Santa Restituta Brunello di Montalcino', 'toast', 15, 'non_oak')
# ('Pieve Santa Restituta Rennina Brunello di Montalcino', 'coffee', 22, 'non_oak')
# ('Pieve Santa Restituta Rennina Brunello di Montalcino', 'coffee', 22, 'oak')
# ('Pingus', 'coffee', 24, 'non_oak')
# ('Pingus', 'coffee', 24, 'oak')
# ('Pinotage', 'coffee', 17, 'non_oak')
# ('Pinotage', 'coffee', 17, 'oak')
# ('Pinotage', 'toast', 17, 'microbio')
# ('Pinotage', 'toast', 17, 'non_oak')
# ("Poggio all'Oro Brunello di Montalcino Riserva", 'coffee', 17, 'non_oak')
# ...
# ('Relentless', 'coffee', 22, 'non_oak')
# ('Relentless', 'coffee', 22, 'oak')
# ('Relentless', 'cream', 11, 'microbio')
# ('Reserva Ribera del Duero', 'coffee', 26, 'non_oak')
# ('Reserva Ribera del Duero', 'coffee', 26, 'oak')
# ('Reserva Ribera del Duero', 'cream', 13, 'microbio')
# ('Reserva Ribera del Duero', 'toast', 12, 'microbio')
# ('Reserva Ribera del Duero', 'toast', 12, 'non_oak')
# ('Reserve Chardonnay', 'citrus', 41, 'citrus_fruit')
# ('Reserve Chardonnay', 'cream', 17, 'microbio')
# ('Reserve Pinotage', 'coffee', 15, 'non_oak')
# ('Reserve Pinotage', 'coffee', 15, 'oak')
# ('Reserve Pinotage', 'cream', 13, 'microbio')
# ('Ribera del Duero', 'coffee', 192, 'non_oak')
# ('Ribera del Duero', 'coffee', 192, 'oak')
# ('Ribera del Duero', 'cream', 73, 'microbio')
# ('Ribera del Duero', 'toast', 59, 'microbio')
# ('Ribera del Duero', 'toast', 59, 'non_oak')
# ('Ribera del Duero Reserva', 'coffee', 42, 'non_oak')
# ('Ribera del Duero Reserva', 'coffee', 42, 'oak')
# ('Ribera del Duero Reserva', 'toast', 22, 'microbio')
# ('Ribera del Duero Reserva', 'toast', 22, 'non_oak')
# ('Ribolla Gialla', 'citrus', 49, 'citrus_fruit')
# ('Ribolla Gialla', 'cream', 14, 'microbio')
# ('Rioja Blanco Reserva', 'cream', 14, 'microbio')
# ('Rioja Reserva', 'coffee', 28, 'non_oak')
# ('Rioja Reserva', 'coffee', 28, 'oak')
# ('Rioja Reserva', 'cream', 16, 'microbio')
# ('Riserva Nova Domus Terlaner', 'citrus', 39, 'citrus_fruit')
# ('Riserva Nova Domus Terlaner', 'cream', 41, 'microbio')
# ('Roda I Reserva Rioja', 'coffee', 69, 'non_oak')
# ('Roda I Reserva Rioja', 'coffee', 69, 'oak')
# ('Roda I Reserva Rioja', 'cream', 41, 'microbio')
# ('Roda I Reserva Rioja', 'toast', 20, 'microbio')
# ('Roda I Reserva Rioja', 'toast', 20, 'non_oak')
# ('Rosé', 'citrus', 43, 'citrus_fruit')
# ('Rosé', 'cream', 56, 'microbio')
# ('Rosé', 'toast', 65, 'microbio')
# ('Rosé', 'toast', 65, 'non_oak')
# ("Rosé Brut Champagne Grand Cru 'Ambonnay'", 'citrus', 42, 'citrus_fruit')
# ("Rosé Brut Champagne Grand Cru 'Ambonnay'", 'cream', 47, 'microbio')
# ("Rosé Brut Champagne Grand Cru 'Ambonnay'", 'toast', 26, 'microbio')
# ("Rosé Brut Champagne Grand Cru 'Ambonnay'", 'toast', 26, 'non_oak')
# ('Rubicon', 'coffee', 23, 'non_oak')
# ('Rubicon', 'coffee', 23, 'oak')
# ('Rubicon', 'cream', 12, 'microbio')
# ('Rutherford', 'coffee', 15, 'non_oak')
# ('Rutherford', 'coffee', 15, 'oak')
# ('Rutherford', 'cream', 20, 'microbio')
# ('S.L.V. Cabernet Sauvignon', 'coffee', 38, 'non_oak')
# ('S.L.V. Cabernet Sauvignon', 'coffee', 38, 'oak')
# ('Saffredi', 'coffee', 33, 'non_oak')
# ('Saffredi', 'coffee', 33, 'oak')
# ('Saffredi', 'cream', 21, 'microbio')
# ('Saint-Emilion Grand Cru (Premier Grand Cru Classé)', 'coffee', 13, 'non_oak')
# ('Saint-Emilion Grand Cru (Premier Grand Cru Classé)', 'coffee', 13, 'oak')
# ('Saint-Estèphe (Grand Cru Classé)', 'coffee', 94, 'non_oak')
# ('Saint-Estèphe (Grand Cru Classé)', 'coffee', 94, 'oak')
# ('Saint-Estèphe (Grand Cru Classé)', 'cream', 39, 'microbio')
# ('Saint-Estèphe (Grand Cru Classé)', 'toast', 35, 'microbio')
# ('Saint-Estèphe (Grand Cru Classé)', 'toast', 35, 'non_oak')
# ('Saint-Julien (Grand Cru Classé)', 'citrus', 27, 'citrus_fruit')
# ('Saint-Julien (Grand Cru Classé)', 'coffee', 666, 'non_oak')
# ('Saint-Julien (Grand Cru Classé)', 'coffee', 666, 'oak')
# ('Saint-Julien (Grand Cru Classé)', 'cream', 232, 'microbio')
# ('Saint-Julien (Grand Cru Classé)', 'toast', 188, 'microbio')
# ('Saint-Julien (Grand Cru Classé)', 'toast', 188, 'non_oak')
# ('Saint-Émilion Grand Cru', 'coffee', 113, 'non_oak')
# ('Saint-Émilion Grand Cru', 'coffee', 113, 'oak')
# ('Saint-Émilion Grand Cru', 'cream', 32, 'microbio')
# ('Saint-Émilion Grand Cru (Grand Cru Classé)', 'coffee', 15, 'non_oak')
# ('Saint-Émilion Grand Cru (Grand Cru Classé)', 'coffee', 15, 'oak')
# ('Saint-Émilion Grand Cru (Premier Grand Cru Classé)', 'citrus', 22, 'citrus_fruit')
# ('Saint-Émilion Grand Cru (Premier Grand Cru Classé)', 'coffee', 535, 'non_oak')
# ('Saint-Émilion Grand Cru (Premier Grand Cru Classé)', 'coffee', 535, 'oak')
# ('Saint-Émilion Grand Cru (Premier Grand Cru Classé)', 'cream', 191, 'microbio')
# ('Saint-Émilion Grand Cru (Premier Grand Cru Classé)', 'toast', 115, 'microbio')
# ('Saint-Émilion Grand Cru (Premier Grand Cru Classé)', 'toast', 115, 'non_oak')
# ('San Vicente Rioja', 'coffee', 38, 'non_oak')
# ('San Vicente Rioja', 'coffee', 38, 'oak')
# ('San Vicente Rioja', 'toast', 14, 'microbio')
# ('San Vicente Rioja', 'toast', 14, 'non_oak')
# ('Saperavi', 'coffee', 14, 'non_oak')
# ('Saperavi', 'coffee', 14, 'oak')
# ('Sassicaia', 'citrus', 16, 'citrus_fruit')
# ('Sassicaia', 'coffee', 179, 'non_oak')
# ('Sassicaia', 'coffee', 179, 'oak')
# ('Sassicaia', 'cream', 75, 'microbio')
# ('Sassicaia', 'toast', 47, 'microbio')
# ('Sassicaia', 'toast', 47, 'non_oak')
# ('Sauternes', 'citrus', 207, 'citrus_fruit')
# ('Sauternes', 'coffee', 26, 'non_oak')
# ('Sauternes', 'coffee', 26, 'oak')
# ('Sauternes', 'cream', 215, 'microbio')
# ('Sauternes', 'green apple', 13, 'tree_fruit')
# ('Sauternes', 'toast', 49, 'microbio')
# ('Sauternes', 'toast', 49, 'non_oak')
# ('Sauternes (Premier Grand Cru Classé)', 'citrus', 267, 'citrus_fruit')
# ('Sauternes (Premier Grand Cru Classé)', 'coffee', 29, 'non_oak')
# ('Sauternes (Premier Grand Cru Classé)', 'coffee', 29, 'oak')
# ('Sauternes (Premier Grand Cru Classé)', 'cream', 277, 'microbio')
# ('Sauternes (Premier Grand Cru Classé)', 'green apple', 14, 'tree_fruit')
# ('Sauternes (Premier Grand Cru Classé)', 'toast', 81, 'microbio')
# ('Sauternes (Premier Grand Cru Classé)', 'toast', 81, 'non_oak')
# ('Scharzhofberger Riesling Auslese', 'citrus', 14, 'citrus_fruit')
# ('Scharzhofberger Riesling Auslese', 'cream', 13, 'microbio')
# ('Scharzhofberger Riesling Kabinett', 'citrus', 72, 'citrus_fruit')
# ('Scharzhofberger Riesling Kabinett', 'cream', 16, 'microbio')
# ('Scharzhofberger Riesling Kabinett', 'green apple', 36, 'tree_fruit')
# ('Scharzhofberger Riesling Spätlese', 'citrus', 38, 'citrus_fruit')
# ('Scrio', 'coffee', 16, 'non_oak')
# ('Scrio', 'coffee', 16, 'oak')
# ('Series C', 'coffee', 25, 'non_oak')
# ('Series C', 'coffee', 25, 'oak')
# ('Series M', 'coffee', 11, 'non_oak')
# ('Series M', 'coffee', 11, 'oak')
# ('Serral del Vell Brut Nature', 'citrus', 28, 'citrus_fruit')
# ('Serral del Vell Brut Nature', 'cream', 38, 'microbio')
# ('Serral del Vell Brut Nature', 'toast', 30, 'microbio')
# ('Serral del Vell Brut Nature', 'toast', 30, 'non_oak')
# ('Siepi', 'coffee', 35, 'non_oak')
# ('Siepi', 'coffee', 35, 'oak')
# ('Siepi', 'toast', 13, 'microbio')
# ('Siepi', 'toast', 13, 'non_oak')
# ('Silex', 'citrus', 185, 'citrus_fruit')
# ('Silex', 'cream', 45, 'microbio')
# ('Silex', 'green apple', 48, 'tree_fruit')
# ('Silex', 'toast', 13, 'microbio')
# ('Silex', 'toast', 13, 'non_oak')
# ('Sir Winston Churchill Brut Champagne', 'citrus', 408, 'citrus_fruit')
# ('Sir Winston Churchill Brut Champagne', 'coffee', 13, 'non_oak')
# ('Sir Winston Churchill Brut Champagne', 'coffee', 13, 'oak')
# ('Sir Winston Churchill Brut Champagne', 'cream', 290, 'microbio')
# ('Sir Winston Churchill Brut Champagne', 'green apple', 127, 'tree_fruit')
# ('Sir Winston Churchill Brut Champagne', 'toast', 282, 'microbio')
# ('Sir Winston Churchill Brut Champagne', 'toast', 282, 'non_oak')
# ('Solare Toscana', 'coffee', 31, 'non_oak')
# ('Solare Toscana', 'coffee', 31, 'oak')
# ('Sorì San Lorenzo', 'coffee', 12, 'non_oak')
# ('Sorì San Lorenzo', 'coffee', 12, 'oak')
# ('Special Selection Cabernet Sauvignon', 'coffee', 81, 'non_oak')
# ('Special Selection Cabernet Sauvignon', 'coffee', 81, 'oak')
# ('Special Selection Cabernet Sauvignon', 'cream', 82, 'microbio')
# ('Special Selection Cabernet Sauvignon', 'toast', 25, 'microbio')
# ('Special Selection Cabernet Sauvignon', 'toast', 25, 'non_oak')
# ('Sperss Barolo', 'coffee', 13, 'non_oak')
# ('Sperss Barolo', 'coffee', 13, 'oak')
# ('Sperss Barolo', 'cream', 15, 'microbio')
# ('St. Henri Shiraz', 'coffee', 65, 'non_oak')
# ('St. Henri Shiraz', 'coffee', 65, 'oak')
# ('St. Henri Shiraz', 'cream', 29, 'microbio')
# ('TD9', 'coffee', 56, 'non_oak')
# ('TD9', 'coffee', 56, 'oak')
# ('Tenuta Guado al Tasso Bolgheri Superiore', 'coffee', 117, 'non_oak')
# ('Tenuta Guado al Tasso Bolgheri Superiore', 'coffee', 117, 'oak')
# ('Tenuta Guado al Tasso Bolgheri Superiore', 'cream', 28, 'microbio')
# ('Tenuta Guado al Tasso Bolgheri Superiore', 'toast', 22, 'microbio')
# ('Tenuta Guado al Tasso Bolgheri Superiore', 'toast', 22, 'non_oak')
# ('Tenuta Nuova Brunello di Montalcino', 'coffee', 65, 'non_oak')
# ('Tenuta Nuova Brunello di Montalcino', 'coffee', 65, 'oak')
# ('Tenuta Nuova Brunello di Montalcino', 'cream', 22, 'microbio')
# ("Tenuta Tignanello 'Solaia'", 'coffee', 100, 'non_oak')
# ("Tenuta Tignanello 'Solaia'", 'coffee', 100, 'oak')
# ("Tenuta Tignanello 'Solaia'", 'cream', 33, 'microbio')
# ("Tenuta Tignanello 'Solaia'", 'toast', 19, 'microbio')
# ("Tenuta Tignanello 'Solaia'", 'toast', 19, 'non_oak')
# ('Tessons Clos de Mon Plaisir Meursault', 'citrus', 24, 'citrus_fruit')
# ('The Armagh Shiraz', 'coffee', 18, 'non_oak')
# ('The Armagh Shiraz', 'coffee', 18, 'oak')
# ('The Armagh Shiraz', 'cream', 12, 'microbio')
# ('Tignanello', 'citrus', 15, 'citrus_fruit')
# ('Tignanello', 'coffee', 271, 'non_oak')
# ('Tignanello', 'coffee', 271, 'oak')
# ('Tignanello', 'cream', 96, 'microbio')
# ('Tignanello', 'toast', 61, 'microbio')
# ('Tignanello', 'toast', 61, 'non_oak')
# ('Tinto', 'coffee', 59, 'non_oak')
# ('Tinto', 'coffee', 59, 'oak')
# ('Tinto', 'cream', 40, 'microbio')
# ('Tinto', 'toast', 24, 'microbio')
# ('Tinto', 'toast', 24, 'non_oak')
# ('Tokaji Aszú 3 Puttonyos', 'citrus', 41, 'citrus_fruit')
# ('Tokaji Aszú 3 Puttonyos', 'cream', 18, 'microbio')
# ('Tokaji Aszú 5 Puttonyos', 'citrus', 47, 'citrus_fruit')
# ('Tokaji Aszú 5 Puttonyos', 'cream', 24, 'microbio')
# ('Tokaji Aszú 5 Puttonyos', 'toast', 30, 'microbio')
# ('Tokaji Aszú 5 Puttonyos', 'toast', 30, 'non_oak')
# ('Tokaji Aszú 6 Puttonyos', 'citrus', 32, 'citrus_fruit')
# ('Toro', 'coffee', 184, 'non_oak')
# ('Toro', 'coffee', 184, 'oak')
# ('Toro', 'cream', 60, 'microbio')
# ('Toro', 'toast', 58, 'microbio')
# ('Toro', 'toast', 58, 'non_oak')
# ('Torre Muga', 'coffee', 32, 'non_oak')
# ('Torre Muga', 'coffee', 32, 'oak')
# ('Torre Muga', 'cream', 18, 'microbio')
# ('Torre Muga', 'toast', 18, 'microbio')
# ('Torre Muga', 'toast', 18, 'non_oak')
# ('Toscana', 'coffee', 69, 'non_oak')
# ('Toscana', 'coffee', 69, 'oak')
# ('Toscana', 'cream', 29, 'microbio')
# ('Toscana', 'toast', 23, 'microbio')
# ('Toscana', 'toast', 23, 'non_oak')
# ('Toscana Batar', 'citrus', 50, 'citrus_fruit')
# ('Toscana Batar', 'cream', 76, 'microbio')
# ('Toscana Batar', 'green apple', 13, 'tree_fruit')
# ('Toscana Batar', 'toast', 19, 'microbio')
# ('Toscana Batar', 'toast', 19, 'non_oak')
# ('Toscana Bianco', 'citrus', 20, 'citrus_fruit')
# ('Toscana Bianco', 'cream', 12, 'microbio')
# ('Toscana Bianco', 'green apple', 16, 'tree_fruit')
# ('Toscana Camartina', 'coffee', 13, 'non_oak')
# ('Toscana Camartina', 'coffee', 13, 'oak')
# ('Toscana I Sodi di San Niccolo', 'coffee', 21, 'non_oak')
# ('Toscana I Sodi di San Niccolo', 'coffee', 21, 'oak')
# ('Toscana Rosso', 'coffee', 14, 'non_oak')
# ('Toscana Rosso', 'coffee', 14, 'oak')
# ('Trasnocho', 'coffee', 11, 'non_oak')
# ('Trasnocho', 'coffee', 11, 'oak')
# ("Trebbiano d'Abruzzo", 'citrus', 64, 'citrus_fruit')
# ("Trebbiano d'Abruzzo", 'coffee', 21, 'non_oak')
# ("Trebbiano d'Abruzzo", 'coffee', 21, 'oak')
# ("Trebbiano d'Abruzzo", 'cream', 28, 'microbio')
# ("Trebbiano d'Abruzzo", 'green apple', 19, 'tree_fruit')
# ("Trebbiano d'Abruzzo", 'toast', 11, 'microbio')
# ("Trebbiano d'Abruzzo", 'toast', 11, 'non_oak')
# ('Turriga Isola dei Nuraghi', 'coffee', 36, 'non_oak')
# ('Turriga Isola dei Nuraghi', 'coffee', 36, 'oak')
# ('Unico', 'citrus', 11, 'citrus_fruit')
# ('Unico', 'coffee', 117, 'non_oak')
# ('Unico', 'coffee', 117, 'oak')
# ('Unico', 'cream', 53, 'microbio')
# ('Unico', 'toast', 38, 'microbio')
# ('Unico', 'toast', 38, 'non_oak')
# ('Unico Reserva Especial Edición', 'coffee', 20, 'non_oak')
# ('Unico Reserva Especial Edición', 'coffee', 20, 'oak')
# ('Unico Reserva Especial Edición', 'cream', 11, 'microbio')
# ("V.P Extra Brut Champagne Grand Cru 'Ambonnay'", 'citrus', 63, 'citrus_fruit')
# ("V.P Extra Brut Champagne Grand Cru 'Ambonnay'", 'cream', 31, 'microbio')
# ("V.P Extra Brut Champagne Grand Cru 'Ambonnay'", 'green apple', 26, 'tree_fruit')
# ("V.P Extra Brut Champagne Grand Cru 'Ambonnay'", 'toast', 52, 'microbio')
# ("V.P Extra Brut Champagne Grand Cru 'Ambonnay'", 'toast', 52, 'non_oak')
# ('VIK', 'coffee', 11, 'non_oak')
# ('VIK', 'coffee', 11, 'oak')
# ('VV 26 Blanc de Blancs Vieilles Vignes Grand Cru Brut', 'toast', 11, 'microbio')
# ('VV 26 Blanc de Blancs Vieilles Vignes Grand Cru Brut', 'toast', 11, 'non_oak')
# ('Valbuena 5º', 'coffee', 122, 'non_oak')
# ('Valbuena 5º', 'coffee', 122, 'oak')
# ('Valbuena 5º', 'cream', 60, 'microbio')
# ('Valbuena 5º', 'toast', 69, 'microbio')
# ('Valbuena 5º', 'toast', 69, 'non_oak')
# ('Valpolicella Classico Superiore', 'coffee', 36, 'non_oak')
# ('Valpolicella Classico Superiore', 'coffee', 36, 'oak')
# ('Valpolicella Classico Superiore', 'cream', 12, 'microbio')
# ('Valpolicella Superiore Monte Lodoletta', 'coffee', 61, 'non_oak')
# ('Valpolicella Superiore Monte Lodoletta', 'coffee', 61, 'oak')
# ('Valpolicella Superiore Monte Lodoletta', 'cream', 11, 'microbio')
# ('Vecchie Vigne Brunello di Montalcino', 'coffee', 12, 'non_oak')
# ('Vecchie Vigne Brunello di Montalcino', 'coffee', 12, 'oak')
# ('Veneto Alzero Cabernet', 'coffee', 15, 'non_oak')
# ('Veneto Alzero Cabernet', 'coffee', 15, 'oak')
# ('Veneto Rosso del Bepi', 'coffee', 15, 'non_oak')
# ('Veneto Rosso del Bepi', 'coffee', 15, 'oak')
# ('Victorino', 'coffee', 39, 'non_oak')
# ('Victorino', 'coffee', 39, 'oak')
# ('Victorino', 'cream', 15, 'microbio')
# ('Victorino', 'toast', 24, 'microbio')
# ('Victorino', 'toast', 24, 'non_oak')
# ('Vieilles Vignes Châteauneuf-du-Pape Blanc', 'citrus', 17, 'citrus_fruit')
# ('Vieilles Vignes Châteauneuf-du-Pape Blanc', 'cream', 38, 'microbio')
# ('Vieilles Vignes Châteauneuf-du-Pape Blanc', 'toast', 11, 'microbio')
# ('Vieilles Vignes Châteauneuf-du-Pape Blanc', 'toast', 11, 'non_oak')
# ('Vieilles Vignes Meursault', 'citrus', 33, 'citrus_fruit')
# ('Vieilles Vignes Meursault', 'cream', 17, 'microbio')
# ('Vigna Cappella di S. Stefano Perno Barolo', 'coffee', 15, 'non_oak')
# ('Vigna Cappella di S. Stefano Perno Barolo', 'coffee', 15, 'oak')
# ('Vigne Vecchie Gold Series Leggenda Primitivo di Manduria', 'coffee', 17, 'non_oak')
# ('Vigne Vecchie Gold Series Leggenda Primitivo di Manduria', 'coffee', 17, 'oak')
# ('Vin Santo di Montepulciano Occhio di Pernice', 'coffee', 15, 'non_oak')
# ('Vin Santo di Montepulciano Occhio di Pernice', 'coffee', 15, 'oak')
# ('Vin de Constance (Natural Sweet)', 'citrus', 129, 'citrus_fruit')
# ('Vin de Constance (Natural Sweet)', 'coffee', 13, 'non_oak')
# ('Vin de Constance (Natural Sweet)', 'coffee', 13, 'oak')
# ('Vin de Constance (Natural Sweet)', 'cream', 81, 'microbio')
# ('Vin de Constance (Natural Sweet)', 'toast', 18, 'microbio')
# ('Vin de Constance (Natural Sweet)', 'toast', 18, 'non_oak')
# ('Vintage', 'citrus', 406, 'citrus_fruit')
# ('Vintage', 'coffee', 56, 'non_oak')
# ('Vintage', 'coffee', 56, 'oak')
# ('Vintage', 'cream', 240, 'microbio')
# ('Vintage', 'green apple', 96, 'tree_fruit')
# ('Vintage', 'toast', 356, 'microbio')
# ('Vintage', 'toast', 356, 'non_oak')
# ('Vintage Port', 'coffee', 26, 'non_oak')
# ('Vintage Port', 'coffee', 26, 'oak')
# ('Vintage Port', 'cream', 18, 'microbio')
# ('Vittorio Moretti', 'citrus', 27, 'citrus_fruit')
# ('Vittorio Moretti', 'cream', 12, 'microbio')
# ('Vittorio Moretti', 'toast', 22, 'microbio')
# ('Vittorio Moretti', 'toast', 22, 'non_oak')
# ('Viña El Pison', 'coffee', 13, 'non_oak')
# ('Viña El Pison', 'coffee', 13, 'oak')
# ('Viña El Pison', 'cream', 12, 'microbio')
# ("Vénus Blanc de Blancs Brut Nature Champagne Grand Cru 'Avize'", 'citrus', 21, 'citrus_fruit')
# ("Vénus Blanc de Blancs Brut Nature Champagne Grand Cru 'Avize'", 'green apple', 13, 'tree_fruit')
# ('Vürsù Barbaresco Starderi', 'coffee', 16, 'non_oak')
# ('Vürsù Barbaresco Starderi', 'coffee', 16, 'oak')
# ('Vürsù Barolo Campè', 'coffee', 13, 'non_oak')
# ('Vürsù Barolo Campè', 'coffee', 13, 'oak')
# ('Yarden Katzrin', 'coffee', 17, 'non_oak')
# ('Yarden Katzrin', 'coffee', 17, 'oak')
# ("d'Alceo", 'coffee', 12, 'non_oak')
# ("d'Alceo", 'coffee', 12, 'oak')

# %% [markdown]
# ### 5. We would like to select wines that are easy to find all over the world. Find the top 3 most common grape all over the world and for each grape, give us the the 5 best rated wines.
